# %%
## Read the labelled files and the poly_user
def get_git_root(path):
	git_repo = git.Repo(path, search_parent_directories=True)
	git_root = git_repo.git.rev_parse("--show-toplevel")
	return git_root

# %%
import os
import pandas as pd
import sys

# %%
from src.data_extraction.

# %%
top_dir = "/home/drew_william2345/twitter_juul"
# top_dir = os.path.join(get_git_root(os.getcwd()))
input_dir = os.path.join(top_dir,"input")
embeddings_dir  = os.path.join(top_dir,"input","embeddings")
annotatted_dir = os.path.join(input_dir,"annotated_data")
classifier_dir = os.path.join(top_dir,"models","classifier")
model_dir = os.path.join(top_dir,"models")
poly_dir = os.path.join(top_dir,"poly_users")

# %%
## lets get the location data for the users

# %%
df_tweets = pd.read_csv(os.path.join(input_dir,"consolidated_data","timeline_tweets.csv"), lineterminator="\n")
# Out:
# /home/drew_william2345/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
len(df_tweets)
# Out:
# 120470

# %%
## getting the user location
len(df_tweets.userID.unique())
# Out:
# 4857

# %%
## getting just the user information - getting the first tweet of each user
users = df_tweets.userID.unique()
users_visited = set()
df_users = []
for index,row in df_tweets.iterrows():
    if (row.userID) in users_visited:
        continue
    else:
        df_users.append(row)
        users_visited.add(row.userID)

# %%
df_users = pd.DataFrame(df_users,columns = list(df_tweets.columns))

# %%
(df_users.userLocation)
# Out:
# 0         Washington, DC
# 1         NaN
# 2         Seoul, Korea
# 3         Texas Tech University
# 4         San Diego, California
# 5         Los Angeles, California
# 8         BU School of Public Health
# 10        The Continental United States
# 12        Vancouver
# 14        In the vicinity of a big river
# 18        We Support NOTBlowingSmoke.org
# 24        Gray, Maine
# 58        Bryan, TX
# 72        Washington, D.C.
# 73        NaN
# 74        India
# 80        NaN
# 81        Chicago,IL
# 82        Milan, Italy
# 86        NaN
# 92        California (o/18 :-)
# 94        VA • Wisconsin • LA
# 109       Everywhere
# 116       USA
# 127       NaN
# 128       Montréal
# 129       Auckland, Aotearoa/NZ
# 156       New YORK
# 157       Philadelphia, PA
# 165       NaN
# 169       tunisie
# 205       Colorado
# 206       San Francisco, CA
# 211       winston-salem nc
# 213       Long Island, NY, United States
# 215       Dublin, Ohio
# 222       Lacey, NJ
# ...

# %%
## as string can be quite varied we might need either a dict of all states and then can do regex or
## use twiitter api to determine geo location or predetermined state and conutry tags  (using derived - user object)

# %%
## gathering geo cordiantes and state, country codes..
