# %% [markdown]
# ### aim to predict the escalation of users using lstm and compare with other baseline classfiers

# %%
import os
import sys
import git
import pickle
import numpy as np

# %%
## Read the labelled files and the poly_user
def get_git_root(path):
	git_repo = git.Repo(path, search_parent_directories=True)
	git_root = git_repo.git.rev_parse("--show-toplevel")
	return git_root

# %%
top_dir = os.path.join(get_git_root(os.getcwd()))
input_dir = os.path.join(get_git_root(os.getcwd()),"input")
embeddings_dir  = os.path.join(get_git_root(os.getcwd()),"input","embeddings")
annotatted_dir = os.path.join(input_dir,"annotated_data")
classifier_dir = os.path.join(get_git_root(os.getcwd()),"models","classifier")
model_dir = os.path.join(get_git_root(os.getcwd()),"models")
poly_dir = os.path.join(model_dir,"poly_users")

# %%
## insert the escalation dir
sys.path.insert(0, os.path.join(top_dir,"src","preprocess","escalation"))

# %%
# %load_ext autoreload
# %autoreload 2
import os
import sys

# %%
## importing the library function
module_path = os.path.abspath(top_dir)
if module_path not in sys.path:
    sys.path.append(module_path)
from src.preprocess.escalation import driver
from sklearn.linear_model import LogisticRegression
import pandas as pd
# Out:
# Using TensorFlow backend.
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/xavlock2345/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/xavlock2345/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
poly_users = pickle.load(open(os.path.join(poly_dir,"poly_users.pkl"),"rb"))
regular_users = pickle.load(open(os.path.join(poly_dir,"regular_users.pkl"),"rb"))
mono_users = pickle.load(open(os.path.join(poly_dir,"mono_users.pkl"),"rb"))

# %%
first_data = pd.read_csv(os.path.join(input_dir,"user_first.csv"),lineterminator="\n")
juul_data = pd.read_csv(os.path.join(input_dir,"juul_data.csv"),lineterminator="\n")

# %%
## we taking data from juul and weed and not use the pattern
juul_data["tweetCreatedAt"] = pd.to_datetime(juul_data["tweetCreatedAt"])
# ## filter the juul data to capture just the regualr users
juul_data = juul_data.loc[juul_data.userID.isin(regular_users)]

# ## we keep only the regular usrs
first_data = first_data.loc[first_data.userID.isin(regular_users)]

## we look at weed first and juul first tweets
first_data["weed_first"] = pd.to_datetime(first_data["weed_first"])
first_data["juul_first"] = pd.to_datetime(first_data["juul_first"])

# %%
## so will train the classfier on the bucket data

# %%
## bucket the users in bucket :
#1 2015 - [2015-2018] 
#2 2015- 2016 - [17 - 18]
#3 2015 - 2017 - [18]

# %% [markdown]
# ### looking at sequence of scores in year based interval

# %% [markdown]
# ## Year level

# %%
## lok at the prediction accuracy fo classfier for different range intervals
## 2015 - 
## 2015 -16
## 2015 - 17
## juul_data and first_data
## lstm - sequence, without
## svm
## xgboost ..done

# %%
import util
import driver
import preprocessing
import lstm as lstm_module
import baselines
import pickle
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### preparing data

# %%
poly_users = pickle.load(open(os.path.join(poly_dir,"poly_users.pkl"),"rb"))
regular_users = pickle.load(open(os.path.join(poly_dir,"regular_users.pkl"),"rb"))
mono_users = pickle.load(open(os.path.join(poly_dir,"mono_users.pkl"),"rb"))

# %%
## input data :juul_data 
juul_data = pd.read_csv(os.path.join(input_dir,"juul_data.csv"),lineterminator="\n")
juul_data["tweetCreatedAt"] = pd.to_datetime(juul_data["tweetCreatedAt"])
juul_data = juul_data.loc[juul_data.userID.isin(regular_users)]

# ## look at the weed first and juul_first tweet
first_data = pd.read_csv(os.path.join(input_dir,"user_first.csv"),lineterminator="\n")
first_data = first_data.loc[first_data.userID.isin(regular_users)]  # reg users
first_data["weed_first"] = pd.to_datetime(first_data["weed_first"])
first_data["juul_first"] = pd.to_datetime(first_data["juul_first"])

# %%
## removing the rewteet text column completely
ids_ = juul_data.loc[juul_data['retweetText'].notnull()]["tweetId"]
juul_data.loc[juul_data.tweetId.isin(ids_),"tweetText"] = juul_data.loc[juul_data.tweetId.isin(ids_)]["retweetText"]
juul_data = juul_data.drop(["hashtags","retweetText"],axis=1)
len(juul_data) ## 1353987 (sanity check)
# Out:
# 1353987

# %%
len(juul_data) ## 1353987
len(juul_data.userID.unique()) ## 673724  reg users
# Out:
# 673724

# %%
## gathering data in different range of intervals
bucket_data = []
bucket_data.append(preprocessing.get_year_data(2015,first_data,juul_data))
bucket_data.append(preprocessing.get_year_data(2016,first_data,juul_data))
bucket_data.append(preprocessing.get_year_data(2017,first_data,juul_data))
# Out:
# year 2015
# users that will change 97
# total users 1049
# length of data 2944
# year 2016
# users that will change 313
# total users 1636
# length of data 6475
# year 2017
# users that will change 9525
# total users 40236
# length of data 111735

# %% [markdown]
# ## Capture text features

# %%
# oversampling
dimension = 100
epoch = 20
svm_scores = []
rf_scores = []
xgb_scores = []
lstm_scores = []
Y_tests = []
for year,data,users_labelled in bucket_data:
    train_data,test_data,Y_train, Y_test = preprocessing.prepare_data(data,users_labelled)
    
    # lstm model
    lstm_score, lstm_pred, lstm_model, keras_tkzr, max_len= driver.run_lstm(
                                        train_data["tweetText"],test_data["tweetText"],Y_train, Y_test,
                                        dimension,epoch,cross_splits=5,option="over",cross_val= True)
    
    # baseline models
    baseline_models, tfidf, svd =  driver.run_text_features(train_data["tweetText"], test_data["tweetText"], 
                                                            Y_train, Y_test,option="over",
                                                            svd=True,cross_val=True)
    
    svm_scores.append(baseline_models['svm'][1])
    rf_scores.append(baseline_models['rf'][1])
    xgb_scores.append(baseline_models['xgb'][1])
    lstm_scores.append(lstm_score)
    Y_tests.append(Y_test)
# Out:
#   0%|          | 0/1049 [00:00<?, ?it/s]
#
# 100%|██████████| 1049/1049 [00:00<00:00, 45483.28it/s]
#
#   0%|          | 0/1049 [00:00<?, ?it/s]
#
#  29%|██▉       | 306/1049 [00:00<00:00, 3059.29it/s]
#
#  56%|█████▌    | 583/1049 [00:00<00:00, 2965.65it/s]
#
#  77%|███████▋  | 807/1049 [00:00<00:00, 2665.01it/s]
#
# 100%|██████████| 1049/1049 [00:00<00:00, 2616.40it/s]
#
#   0%|          | 0/839 [00:00<?, ?it/s]
#
# 100%|██████████| 839/839 [00:00<00:00, 184909.94it/s]
# train-test split
# max_length 60
# preparing the tokenizer
# vocalb 4707
# creating glove embeddign matrix
#  77%|███████▋  | 31062/40236 [00:27<00:03, 2326.17it/s]
# encoding the data
# X-train (839, 60)
# X-test (210, 60)
# creating lstm model
# compiling the model
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         (None, 60)                0
# _________________________________________________________________
# embedding_6 (Embedding)      (None, 60, 100)           470700
# _________________________________________________________________
# bidirectional_6 (Bidirection (None, 200)               160800
# _________________________________________________________________
# dense_6 (Dense)              (None, 2)                 402
# =================================================================
# Total params: 631,902
# Trainable params: 631,902
# Non-trainable params: 0
# _________________________________________________________________
# None
# training the model with balance dataset
# /home/xavlock2345/twitter_juul/src/preprocess/escalation/driver.py:99: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   verbose=1, batch_size=32, class_weight=weight, )
# Train on 1141 samples, validate on 381 samples
# Epoch 1/20
# 1141/1141 [==============================] - 7s 6ms/step - loss: 1.6355 - acc: 0.6529 - val_loss: 1.5558 - val_acc: 0.1864
# Epoch 2/20
# 1141/1141 [==============================] - 5s 4ms/step - loss: 0.8878 - acc: 0.6950 - val_loss: 1.0508 - val_acc: 0.3228
# Epoch 3/20
# 1141/1141 [==============================] - 5s 4ms/step - loss: 0.5889 - acc: 0.7590 - val_loss: 0.6086 - val_acc: 0.7795
# Epoch 4/20
# 1141/1141 [==============================] - 5s 4ms/step - loss: 0.4124 - acc: 0.8335 - val_loss: 0.4954 - val_acc: 0.7848
# Epoch 5/20
# 1141/1141 [==============================] - 5s 4ms/step - loss: 0.3148 - acc: 0.8668 - val_loss: 0.2754 - val_acc: 0.8819
# Epoch 6/20
# 1141/1141 [==============================] - 5s 4ms/step - loss: 0.2729 - acc: 0.8896 - val_loss: 0.2186 - val_acc: 0.8819
# Epoch 7/20
# 1141/1141 [==============================] - 5s 4ms/step - loss: 0.2135 - acc: 0.9176 - val_loss: 0.1768 - val_acc: 0.9029
# Epoch 8/20
# 1141/1141 [==============================] - 5s 4ms/step - loss: 0.1809 - acc: 0.9281 - val_loss: 0.2125 - val_acc: 0.9029
# Epoch 9/20
# 1141/1141 [==============================] - 5s 4ms/step - loss: 0.1722 - acc: 0.9387 - val_loss: 0.1680 - val_acc: 0.9029
# Epoch 10/20
# 1141/1141 [==============================] - 5s 5ms/step - loss: 0.1436 - acc: 0.9387 - val_loss: 0.1873 - val_acc: 0.9029
# Epoch 11/20
# 1141/1141 [==============================] - 5s 4ms/step - loss: 0.1312 - acc: 0.9422 - val_loss: 0.1209 - val_acc: 0.9239
# Epoch 12/20
# 1141/1141 [==============================] - 5s 4ms/step - loss: 0.1238 - acc: 0.9483 - val_loss: 0.1256 - val_acc: 0.9239
# Epoch 13/20
# 1141/1141 [==============================] - 5s 5ms/step - loss: 0.1235 - acc: 0.9465 - val_loss: 0.1408 - val_acc: 0.9659
# Epoch 14/20
# 1141/1141 [==============================] - 5s 5ms/step - loss: 0.1230 - acc: 0.9535 - val_loss: 0.1451 - val_acc: 0.9029
# Epoch 15/20
# 1141/1141 [==============================] - 5s 4ms/step - loss: 0.1108 - acc: 0.9606 - val_loss: 0.1931 - val_acc: 0.8924
# Epoch 16/20
# 1141/1141 [==============================] - 5s 4ms/step - loss: 0.1027 - acc: 0.9623 - val_loss: 0.1189 - val_acc: 0.9239
# Epoch 17/20
# 1141/1141 [==============================] - 5s 4ms/step - loss: 0.0962 - acc: 0.9614 - val_loss: 0.1407 - val_acc: 0.9134
# Epoch 18/20
# 1141/1141 [==============================] - 5s 4ms/step - loss: 0.0959 - acc: 0.9588 - val_loss: 0.1453 - val_acc: 0.8924
# Epoch 19/20
# 1141/1141 [==============================] - 5s 4ms/step - loss: 0.1006 - acc: 0.9571 - val_loss: 0.1287 - val_acc: 0.9239
# Epoch 20/20
# 1141/1141 [==============================] - 6s 5ms/step - loss: 0.0882 - acc: 0.9632 - val_loss: 0.1637 - val_acc: 0.9134
# generating classfication report
# Accuracy: 88.571428
#   Classification Report of train data:
#               precision    recall  f1-score   support
#
#           0       0.92      0.96      0.94       191
#           1       0.27      0.16      0.20        19
#
# avg / total       0.86      0.89      0.87       210
#
#
# first getting cross val scores
# Train on 1038 samples, validate on 347 samples
# Epoch 1/20
#   32/1038 [..............................] - ETA: 4s - loss: 0.0959 - acc: 0.9688
# /home/xavlock2345/twitter_juul/src/preprocess/escalation/lstm.py:163: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   verbose=1, batch_size=32, class_weight=None, )
# 1038/1038 [==============================] - 5s 4ms/step - loss: 0
20
# 1038/1038 [==============================] - 5s 4ms/step - loss: 0.0770 - acc: 0.9615 - val_loss: 0.4811 - val_acc: 0.8905
# Epoch 13/20
# 1038/1038 [==============================] - 5s 4ms/step - loss: 0.0721 - acc: 0.9634 - val_loss: 0.4997 - val_acc: 0.8847
# Epoch 14/20
# 1038/1038 [==============================] - 5s 4ms/step - loss: 0.0744 - acc: 0.9634 - val_loss: 0.5117 - val_acc: 0.8847
# Epoch 15/20
# 1038/1038 [==============================] - 5s 4ms/step - loss: 0.0737 - acc: 0.9615 - val_loss: 0.5269 - val_acc: 0.8876
# Epoch 16/20
# 1038/1038 [==============================] - 5s 4ms/step - loss: 0.0789 - acc: 0.9615 - val_loss: 0.4975 - val_acc: 0.8905
# Epoch 17/20
# 1038/1038 [==============================] - 5s 4ms/step - loss: 0.0751 - acc: 0.9663 - val_loss: 0.4937 - val_acc: 0.8905
# Epoch 18/20
# 1038/1038 [==============================] - 5s 4ms/step - loss: 0.0746 - acc: 0.9644 - val_loss: 0.4914 - val_acc: 0.8934
# Epoch 19/20
# 1038/1038 [==============================] - 5s 4ms/step - loss: 0.0763 - acc: 0.9615 - val_loss: 0.4995 - val_acc: 0.8905
# Epoch 20/20
# 1038/1038 [==============================] - 5s 4ms/step - loss: 0.0741 - acc: 0.9644 - val_loss: 0.4997 - val_acc: 0.8905
# fold = 1
#   Classification Report:
#               precision    recall  f1-score   support
#
#           0       0.99      0.94      0.97       191
#           1       0.93      0.99      0.96       156
#
# avg / total       0.96      0.96      0.96       347
#
#
# Train on 1039 samples, validate on 347 samples
# Epoch 1/20
# 1039/1039 [==============================] - 5s 4ms/step - loss: 0.0654 - acc: 0.9644 - val_loss: 0.5190 - val_acc: 0.8876
# Epoch 2/20
# 1039/1039 [==============================] - 5s 4ms/step - loss: 0.0628 - acc: 0.9663 - val_loss: 0.5197 - val_acc: 0.8905
# Epoch 3/20
#  224/1039 [=====>........................] - ETA: 3s - loss: 0.0701 - acc: 0.9554

# %%
# dump_scores
scores_over = {"svm_scores" : svm_scores,
               "rf_scores" : rf_scores,
               "lstm" : lstm_scores,
               "xgb" : xgb_scores}

with open(os.path.join(model_dir,"text_over_scores.pkl"),"wb") as f:
    pickle.dump(scores_over,f)

# %% [markdown]
# ## plotting

# %%
from sklearn.metrics import precision_recall_fscore_support
maj_scores_neg = []
maj_scores_pos = []
for Y_test in Y_tests:
    y_pred_neg = [0 for x in range(len(Y_test))]
    y_pred_pos = [1 for x in range(len(Y_test))]
    print("length of Y_test",len(Y_test))
    print("positives in Y_test", (util.get_postives(Y_test)))
    maj_pos = precision_recall_fscore_support(Y_test,y_pred_pos,average=None)[2][0]
    maj_scores_pos.append(maj_pos)
    maj_neg = precision_recall_fscore_support(Y_test,y_pred_neg,average=None)[2][0]
    maj_scores_neg.append(maj_neg)
# Out:
# length of Y_test 210
# positives in Y_test 19
# length of Y_test 328
# positives in Y_test 52
# length of Y_test 8048
# positives in Y_test 1861
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
## oversampling  mono -- should have differnt name so that the plots dont get lost
svm = [ele[0] for ele in svm_scores]
rf = [ele[0] for ele in rf_scores]
xgb = [ele[0] for ele in xgb_scores]
lstm = [ele[0] for ele in lstm_scores]
maj_score_pos = [ele for ele in maj_scores_pos]
maj_score_neg = [ele for ele in maj_scores_neg]
## plotting user features
plt.figure(figsize=(15,7))
years = ["2014-15","2015-16","2016-17"]
plt.plot(years,maj_score_pos,label="majority all change to poly")
plt.plot(years,maj_score_neg,label="majority remain mono")
plt.plot(years,svm,label="svm")
plt.plot(years,rf,label="rf")
plt.plot(years,xgb,label="xg-boost")
plt.plot(years,lstm,label="lstm")
plt.title("Performance of classifiers for predicting mono users using user features")
plt.ylabel("F1 score")
plt.legend()
plt.show()

# %%
## oversampling  poly
svm = [ele[1] for ele in svm_scores]
rf = [ele[1] for ele in rf_scores]
xgb = [ele[1] for ele in xgb_scores]
lstm = [ele[1] for ele in lstm_scores]
maj_score_pos = [ele for ele in maj_scores_pos]
maj_score_neg = [ele for ele in maj_scores_neg]
## plotting user features
plt.figure(figsize=(15,7))
years = ["2014-15","2015-16","2016-17"]
plt.plot(years,maj_score_pos,label="majority all change to poly")
plt.plot(years,maj_score_neg,label="majority remain mono")
plt.plot(years,svm,label="svm")
plt.plot(years,rf,label="rf")
plt.plot(years,xgb,label="xg-boost")
plt.plot(years,lstm,label="lstm")
plt.title("Performance of classifiers for predicting mono users using user features")
plt.ylabel("F1 score")
plt.legend()
plt.show()

# %%
xgb_scores
# Out:
# [array([0.94181006, 0.93002008]),
#  array([0.93699789, 0.92302377]),
#  array([0.72290262, 0.63615109])]

# %%
# downsampling **********
dimension = 100
epoch = 20
svm_scores = []
rf_scores = []
xgb_scores = []
lstm_scores = []
Y_tests = []
for year,data,users_labelled in bucket_data:
    train_data,test_data,Y_train, Y_test = preprocessing.prepare_data(data,users_labelled)
    
    ## lstm model
    lstm_score, lstm_pred, lstm_model, keras_tkzr, max_len= driver.run_lstm(
                                        train_data["tweetText"],test_data["tweetText"],Y_train, Y_test,
                                        dimension,epoch,cross_splits=5,option="down")
    
    # baseline models
    baseline_models, tfidf, svd =  driver.run_text_features(train_data["tweetText"], 
                                            test_data["tweetText"], Y_train, Y_test,option="down")
    
    svm_scores.append(baseline_models['svm'][1])
    rf_scores.append(baseline_models['rf'][1])
    xgb_scores.append(baseline_models['xgb'][1])
    lstm_scores.append(lstm_score)

    Y_tests.append(Y_test)
# Out:
# 100%|██████████| 1049/1049 [00:00<00:00, 48778.01it/s]
# 100%|██████████| 1049/1049 [00:00<00:00, 2483.99it/s]
# 100%|██████████| 839/839 [00:00<00:00, 164586.36it/s]
# train-test split
# max_length 60
# preparing the tokenizer
# vocalb 4707
# creating glove embeddign matrix
# encoding the data
# X-train (839, 60)
# X-test (210, 60)
# creating lstm model
# compiling the model
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         (None, 60)                0
# _________________________________________________________________
# embedding_7 (Embedding)      (None, 60, 100)           470700
# _________________________________________________________________
# bidirectional_7 (Bidirection (None, 200)               160800
# _________________________________________________________________
# dense_7 (Dense)              (None, 2)                 402
# =================================================================
# Total params: 631,902
# Trainable params: 631,902
# Non-trainable params: 0
# _________________________________________________________________
# None
# first getting cross val scores
# Train on 628 samples, validate on 210 samples
# Epoch 1/20
# 628/628 [==============================] - 8s 12ms/step - loss: 1.7041 - acc: 0.8662 - val_loss: 1.2970 - val_acc: 0.9095
# Epoch 2/20
# 628/628 [==============================] - 5s 8ms/step - loss: 1.0217 - acc: 0.9076 - val_loss: 0.7944 - val_acc: 0.9095
# Epoch 3/20
# 628/628 [==============================] - 5s 8ms/step - loss: 0.6619 - acc: 0.9076 - val_loss: 0.5704 - val_acc: 0.9095
# Epoch 4/20
# 628/628 [==============================] - 5s 8ms/step - loss: 0.4847 - acc: 0.9076 - val_loss: 0.4411 - val_acc: 0.9095
# Epoch 5/20
# 628/628 [==============================] - 5s 8ms/step - loss: 0.3764 - acc: 0.9124 - val_loss: 0.3855 - val_acc: 0.9095
# Epoch 6/20
# 628/628 [==============================] - 5s 8ms/step - loss: 0.3280 - acc: 0.9076 - val_loss: 0.3512 - val_acc: 0.9095
# Epoch 7/20
# 628/628 [==============================] - 5s 8ms/step - loss: 0.3040 - acc: 0.9076 - val_loss: 0.3420 - val_acc: 0.9095
# Epoch 8/20
# 628/628 [==============================] - 5s 8ms/step - loss: 0.2740 - acc: 0.9076 - val_loss: 0.3597 - val_acc: 0.9095
# Epoch 9/20
# 628/628 [==============================] - 5s 8ms/step - loss: 0
#   Classification Report:
#               precision    recall  f1-score   support
#
#           0       0.91      0.96      0.93       190
#           1       0.00      0.00      0.00        19
#
# avg / total       0.82      0.87      0.85       209
#
#
# *************
# 0.9651468663950766 0.5304571539865658
# training the model with balance dataset
# Train on 629 samples, validate on 210 samples
# Epoch 1/20
# /home/xavlock2345/twitter_juul/src/preprocess/escalation/driver.py:98: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   verbose=1, batch_size=32, class_weight=weight, )
# 629/629 [==============================] - 5s 8ms/step - loss: 0.0305 - acc: 0.9873 - val_loss: 0.0937 - val_acc: 0.9762
# Epoch 2/20
# 629/629 [==============================] - 5s 8ms/step - loss: 0.0328 - acc: 0.9873 - val_loss: 0.0957 - val_acc: 0.9619
# Epoch 3/20
# 629/629 [==============================] - 5s 8ms/step - loss: 0.0334 - acc: 0.9857 - val_loss: 0.0933 - val_acc: 0.9619
# Epoch 4/20
# 629/629 [==============================] - 5s 8ms/step - loss: 0.0310 - acc: 0.9873 - val_loss: 0.0920 - val_acc: 0.9762
# Epoch 5/20
# 629/629 [==============================] - 5s 8ms/step - loss: 0.0372 - acc: 0.9873 - val_loss: 0.0873 - val_acc: 0.9762
# Epoch 6/20
# 629/629 [==============================] - 5s 8ms/step - loss: 0.0312 - acc: 0.9873 - val_loss: 0.0914 - val_acc: 0.9762
# Epoch 7/20
# 629/629 [==============================] - 5s 8ms/step - loss: 0.0304 - acc: 0.9889 - val_loss: 0.0976 - val_acc: 0.9619
# Epoch 8/20
# 629/629 [==============================] - 5s 8ms/step - loss: 0.0339 - acc: 0.9857 - val_loss: 0.0972 - val_acc: 0.9762
# Epoch 9/20
# 629/629 [==============================] - 5s 8ms/step - loss: 0.0318 - acc: 0.9873 - val_loss: 0.0933 - val_acc: 0.9762
# Epoch 10/20
# 629/629 [==============================] - 5s 8ms/step - loss: 0.0300 - acc: 0.9905 - val_loss: 0.0968 - val_acc: 0.9762
# Epoch 11/20
# 629/629 [==============================] - 5s 8ms/step - loss: 0.0328 - acc: 0.9857 - val_loss: 0.1054 - val_acc: 0.9714
# Epoch 12/20
# 629/629 [==============================] - 5s 8ms/step - loss: 0.0293 - acc: 0.9889 - val_loss: 0.1024 - val_acc: 0.9619
# Epoch 13/20
# 629/629 [==============================] - 5s 8ms/step - loss: 0.0290 - acc: 0.9905 - val_loss: 0.1022 - val_acc: 0.9619
# Epoch 14/20
# 629/629 [==============================] - 5s 8ms/step - loss: 0.0317 - acc: 0.9889 - val_loss: 0.1026 - val_acc: 0.9619
# Epoch 15/20
# 629/629 [==============================] - 5s 8ms/step - loss: 0.0269 - acc: 0.9921 - val_loss: 0.1086 - val_acc: 0.9714
# Epoch 16/20
# 629/629 [==============================] - 5s 8ms/step - loss: 0.0264 - acc: 0.9905 - val_loss: 0.1212 - val_acc: 0.9714
# Epoch 17/20
# 629/629 [==============================] - 5s 8ms/step - loss: 0.0372 - acc: 0.9905 - val_loss: 0.1609 - val_acc: 0.9524
# Epoch 18/20
# 629/629 [==============================] - 5s 8ms/step - loss: 0.0304 - acc: 0.9905 - val_loss: 0.0870 - val_acc: 0.9619
# Epoch 19/20
# 629/629 [==============================] - 5s 8ms/step - loss: 0.0315 - acc: 0.9857 - val_loss: 0.0972 - val_acc: 0.9714
# Epoch 20/20
# 629/629 [==============================] - 5s 8ms/step - loss: 0.0332 - acc: 0.9857 - val_loss: 0.1010 - val_acc: 0.9571
# generating classfication report
# Accuracy: 84.761905
#   Classification Report of train data:
#               precision    recall  f1-score   support
#
#           0       0.91      0.92      0.92       191
#           1       0.12      0.11      0.11        19
#
# avg / total       0.84      0.85      0.84       210
#
#
# lstm cross val score  0.7478020101908212
# job finished
# train data length 839
# total positives before in train 78
# training the models
# X_train shape (839, 100)
# X_test shape (210, 100)
# svm
# [LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear]svm cross val score mean [0.94931501 0.03571429]
#
# random_forest
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# rf cross val score mean [0.95152807 0.        ]
#
# xgBoost
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# 100%|██████████| 1636/1636 [00:00<00:00, 50294.14it/s]
#   0%|          | 0/1636 [00:00<?, ?it/s]
# xgb corss val score mean [0.94720679 0.03405797]
#
# the best model svm
# baseline scores calculated
# 100%|██████████| 1636/1636 [00:00<00:00, 1916.51it/s]
# 100%|██████████| 1308/1308 [00:00<00:00, 191495.33it/s]
# train-test split
# max_length 60
# preparing the tokenizer
# vocalb 6574
# creating glove embeddign matrix
# encoding the data
# X-train (1308, 60)
# X-test (328, 60)
# creating lstm model
# compiling the model
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         (None,
20
# 981/981 [==============================] - 8s 8ms/step - loss: 0.0229 - acc: 0.9908 - val_loss: 0.1144 - val_acc: 0.9755
# Epoch 17/20
# 981/981 [==============================] - 8s 8ms/step - loss: 0.0091 - acc: 0.9959 - val_loss: 0.0910 - val_acc: 0.9786
# Epoch 18/20
# 981/981 [==============================] - 8s 8ms/step - loss: 0.0100 - acc: 0.9949 - val_loss: 0.0974 - val_acc: 0.9817
# Epoch 19/20
# 981/981 [==============================] - 8s 8ms/step - loss: 0.0085 - acc: 0.9969 - val_loss: 0.0979 - val_acc: 0.9786
# Epoch 20/20
# 981/981 [==============================] - 8s 8ms/step - loss: 0.0084 - acc: 0.9949 - val_loss: 0.1022 - val_acc: 0.9786
# generating classfication report
# Accuracy: 76.219512
#   Classification Report of train data:
#               precision    recall  f1-score   support
#
#           0       0.85      0.87      0.86       276
#           1       0.23      0.21      0.22        52
#
# avg / total       0.75      0.76      0.76       328
#
#
# lstm cross val score  0.7867138828703586
# job finished
# train data length 1308
# total positives before in train 207
# training the models
# X_train shape (1308, 100)
# X_test shape (328, 100)
# svm
# [LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear]svm cross val score mean [0.91299394 0.12019467]
#
# random_forest
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# rf cross val score mean [0.91403971 0.        ]
#
# xgBoost
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# xgb corss val score mean [0.90728713 0.13249029]
#
# the best model xgb
# baseline scores calculated
# 100%|██████████| 40236/40236 [00:00<00:00, 68655.64it/s]
# 100%|██████████| 40236/40236 [00:17<00:00, 2298.17it/s]
# 100%|██████████| 32188/32188 [00:00<00:00, 261108.71it/s]
# train-test split
# max_length 60
# preparing the tokenizer
# vocalb 18627
# creating glove embeddign matrix
# encoding the data
# X-train (32188, 60)
# X-test (8048, 60)
# creating lstm model
# compiling the model
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         (None, 60)                0
# _________________________________________________________________
# embedding_9 (Embedding)      (None, 60, 100)           1862700
# _________________________________________________________________
# bidirectional_9 (Bidirection (None, 200)               160800
# _________________________________________________________________
# dense_9 (Dense)              (None, 2)                 402
# =================================================================
# Total params: 2,023,902
# Trainable params: 2,023,902
# Non-trainable params: 0
# _________________________________________________________________
# None
# first getting cross val scores
# /home/xavlock2345/twitter_juul/src/preprocess/escalation/lstm.py:153: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   verbose=1, batch_size=32, class_weight=None, )
# Train on 24141 samples, validate on 8047 samples
# Epoch 1/20
# 24141/24141 [==============================] - 207s 9ms/step - loss: 0.5801 - acc: 0.7700 - val_loss: 0.5115 - val_acc: 0.7712
# Epoch 2/20
# 24141/24141 [==============================] - 203s 8ms/step - loss: 0.4843 - acc: 0.7769 - val_loss: 0.4839 - val_acc: 0.7733
# Epoch 3/20
# 24141/24141 [==============================] - 203s 8ms/step - loss: 0.4694 - acc: 0.7822 - val_loss: 0.4891 - val_acc: 0.7745
# Epoch 4/20
# 24141/24141 [==============================] - 203s 8ms/step - loss: 0.4569 - acc: 0.7857 - val_loss: 0.4867 - val_acc: 0.7697
# Epoch 5/20
# 24141/24141 [==============================] - 203s 8ms/step - loss: 0.4421 - acc: 0.7978 - val_loss: 0.5078 - val_acc: 0.7708
# Epoch 6/20
# 24141/24141 [==============================] - 204s 8ms/step - loss: 0.4235 - acc: 0.8065 - val_loss: 0.5145 - val_acc: 0.7643
# Epoch 7/20
# 24141/24141 [==============================] - 203s 8ms/step - loss: 0.4039 - acc: 0.8191 - val_loss: 0.5273 - val_acc: 0.7534
# Epoch 8/20
# 24141/24141 [==============================] - 204s 8ms/step - loss: 0.3853 - acc: 0.8295 - val_loss: 0.5552 - val_acc: 0.7527
# Epoch 9/20
# 24141/24141 [==============================] - 204s 8ms/step - loss: 0.3695 - acc: 0.8380 - val_loss: 0.5908 - val_acc: 0.7559
# Epoch 10/20
# 24141/24141 [==============================] - 204s 8ms/step - loss: 0.3543 - acc: 0.8440 - val_loss: 0.6042 - val_acc: 0.7562
# Epoch 11/20
# 24141/24141 [==============================] - 204s 8ms/step - loss: 0.3418 - acc: 0.8511 - val_loss: 0.6053 - val_acc: 0.7630
# Epoch 12/20
# 24141/24141 [==============================] - 204s 8ms/step - loss: 0.3271 - acc: 0.8581 - val_loss: 0.6714 - val_acc: 0.7426
# Epoch 13/20
# 24141/24141 [==============================] - 203s 8ms/step - loss: 0
20
# 24141/24141 [==============================] - 202s 8ms/step - loss: 0.1977 - acc: 0.9230 - val_loss: 1.2820 - val_acc: 0.7283
# Epoch 13/20
# 24141/24141 [==============================] - 203s 8ms/step - loss: 0.1970 - acc: 0.9223 - val_loss: 1.2647 - val_acc: 0.7387
# Epoch 14/20
# 24141/24141 [==============================] - 202s 8ms/step - loss: 0.1961 - acc: 0.9240 - val_loss: 1.2981 - val_acc: 0.7387
# Epoch 15/20
# 24141/24141 [==============================] - 202s 8ms/step - loss: 0.1922 - acc: 0.9249 - val_loss: 1.3854 - val_acc: 0.7295
# Epoch 16/20
# 24141/24141 [==============================] - 202s 8ms/step - loss: 0.1840 - acc: 0.9297 - val_loss: 0.3093 - val_acc: 0.9005
# Epoch 6/20
# 24141/24141 [==============================] - 203s 8ms/step - loss: 0.1842 - acc: 0.9279 - val_loss: 0.3190 - val_acc: 0.8974
# Epoch 7/20
# 24141/24141 [==============================] - 203s 8ms/step - loss: 0.1835 - acc: 0.9294 - val_loss: 0.3182 - val_acc: 0.8990
# Epoch 8/20
# 24141/24141 [==============================] - 202s 8ms/step - loss: 0.1820 - acc: 0.9297 - val_loss: 0.3210 - val_acc: 0.8995
# Epoch 9/20
# 24141/24141 [==============================] - 202s 8ms/step - loss: 0.1824 - acc: 0.9279 - val_loss: 0.3227 - val_acc: 0.8966
# Epoch 10/20
# 24141/24141 [==============================] - 202s 8ms/step - loss: 0.1788 - acc: 0.9302 - val_loss: 0.3372 - val_acc: 0.8958
# Epoch 11/20
# 24141/24141 [==============================] - 202s 8ms/step - loss: 0.1785 - acc: 0.9308 - val_loss: 0.3399 - val_acc: 0.8955
# Epoch 12/20
# 24141/24141 [==============================] - 202s 8ms/step - loss: 0.1783 - acc: 0.9313 - val_loss: 0.3498 - val_acc: 0.8928
# Epoch 13/20
# 24141/24141 [==============================] - 203s 8ms/step - loss: 0.1768 - acc: 0.9323 - val_loss: 0.3529 - val_acc: 0.8926
# Epoch 14/20
# 24141/24141 [==============================] - 202s 8ms/step - loss: 0.1804 - acc: 0.9299 - val_loss: 0.3550 - val_acc: 0.8913
# Epoch 15/20
# 24141/24141 [==============================] - 202s 8ms/step - loss: 0.1757 - acc: 0.9323 - val_loss: 0.3564 - val_acc: 0.8904
# Epoch 16/20
# 24141/24141 [==============================] - 202s 8ms/step - loss: 0.1789 - acc: 0.9316 - val_loss: 0.3647 - val_acc: 0.8900
# Epoch 17/20
# 24141/24141 [==============================] - 203s 8ms/step - loss: 0.1774 - acc: 0.9326 - val_loss: 0.3616 - val_acc: 0.8894
# Epoch 18/20
# 12288/24141 [==============>...............] - ETA: 1:32 - loss: 0.1701 - acc: 0.9363

# %%
from sklearn.metrics import precision_recall_fscore_support
maj_scores_neg = []
maj_scores_pos = []
for Y_test in Y_tests:
    y_pred_neg = [0 for x in range(len(Y_test))]
    y_pred_pos = [1 for x in range(len(Y_test))]
    print("length of Y_test",len(Y_test))
    print("positives in Y_test", (util.get_postives(Y_test)))
    maj_pos = precision_recall_fscore_support(Y_test,y_pred_pos,average=None)[2][0]
    maj_scores_pos.append(maj_pos)
    maj_neg = precision_recall_fscore_support(Y_test,y_pred_neg,average=None)[2][0]
    maj_scores_neg.append(maj_neg)
# Out:
# length of Y_test 210
# positives in Y_test 19
# length of Y_test 328
# positives in Y_test 52
# length of Y_test 8048
# positives in Y_test 1861
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
## get distribution of positives in test data..
# dump_scores
import pickle
scores = {"svm_scores" : svm_scores,
               "rf_scores" : rf_scores,
               "lstm" : lstm_scores,
               "xgb" : xgb_scores}

with open(os.path.join(model_dir,"text_under_scores.pkl"),"wb") as f:
    pickle.dump(scores,f)

# %%
#### @TODO look at the plots
scores_under = pickle.load(open(os.path.join(model_dir,"text_under_scores.pkl"),"rb"))
svm_scores =  scores_under["svm_scores"]
rf_scores = scores_under["rf_scores"]
xgb_scores = scores_under["xgb"]
lstm_scores = scores_under["lstm"]

# %%
## downsampling mono
svm = [ele[0] for ele in svm_scores]
rf = [ele[0] for ele in rf_scores]
xgb = [ele[0] for ele in xgb_scores]
lstm = [ele[0] for ele in lstm_scores]
maj_score_pos = [ele for ele in maj_scores_pos]
maj_score_neg = [ele for ele in maj_scores_neg]
## plotting user features
plt.figure(figsize=(15,7))
years = ["2014-15","2015-16","2016-17"]
plt.plot(years,maj_score_pos,label="majority all change to poly")
plt.plot(years,maj_score_neg,label="majority remain mono")
plt.plot(years,svm,label="svm")
plt.plot(years,rf,label="rf")
plt.plot(years,xgb,label="xg-boost")
plt.plot(years,lstm,label="lstm")
plt.title("Performance of classifiers for predicting mono users using user features")
plt.ylabel("F1 score")
plt.legend()
plt.show()

# %%
## downsampling poly
svm = [ele[1] for ele in svm_scores]
rf = [ele[1] for ele in rf_scores]
xgb = [ele[1] for ele in xgb_scores]
lstm = [ele[1] for ele in lstm_scores]
maj_score_pos = [ele for ele in maj_scores_pos]
maj_score_neg = [ele for ele in maj_scores_neg]
## plotting user features
plt.figure(figsize=(15,7))
years = ["2014-15","2015-16","2016-17"]
plt.plot(years,maj_score_pos,label="majority all change to poly")
plt.plot(years,maj_score_neg,label="majority remain mono")
plt.plot(years,svm,label="svm")
plt.plot(years,rf,label="rf")
plt.plot(years,xgb,label="xg-boost")
plt.plot(years,lstm,label="lstm")
plt.title("Performance of classifiers for predicting mono users using user features")
plt.ylabel("F1 score")
plt.legend()
plt.show()

# %%
def plot_model_coeff(model, k, feature_names):
    coef = model.feature_importances_
    top_coefficients = np.argsort(coef)[-k:]
    plt.figure(figsize=(17, 8))
    plt.bar(np.arange(k), coef[top_coefficients], color="blue")
    feature_names = np.array(feature_names)
    plt.xticks(np.arange(k), feature_names[top_coefficients], rotation=60, ha='right', fontsize=20)
    plt.show()

# %% [markdown]
# ### plotting feature importances

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from xgboost import XGBClassifier
import xgboost as xgb
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier
for year,data,users_labelled in bucket_data[1:2]:
    train_data,test_data,Y_train, Y_test = preprocessing.prepare_data(data,users_labelled)
        
#     # baseline models
#     baseline_models, tfidf, svd =  driver.run_text_features(train_data["tweetText"], 
#                                             test_data["tweetText"], Y_train, Y_test,option="over",svd=False)
    train_data = train_data["tweetText"]
    test_data = test_data["tweetText"]
    tf_idf = TfidfVectorizer(sublinear_tf=True)
    tf_idf.fit(train_data)  ## fit on train data

    ## transform train and test data
    X_test = tf_idf.transform(test_data)
    X_train = tf_idf.transform(train_data)
    X_train, Y_train = util.get_oversample(X_train,Y_train)

    X_train = X_train.toarray()  ## because of sparse array
    X_test = X_test.toarray()    ## because of sparse array
    
#     print("svm")
#     svm = LinearSVC(C=1, verbose=1)
#     svm.fit(X_train, Y_train)

#     print("random_forest")
#     rf = RandomForestClassifier(n_estimators=100, max_depth=2,
#                             random_state=0)
#     rf.fit(X_train, Y_train)
    
    print("xgBoost")
#     xgb = XGBClassifier()
#     xgb.fit(X_train, Y_train)
    dtrain = xgb.DMatrix(X_train, label=Y_train,feature_names=tf_idf.get_feature_names())
    xgb_model = xgb.train([],dtrain, verbose_eval=10) #  num_boost_round=60, 
# #                   early_stopping_rounds=50, maximize=False,
# Out:
# 100%|██████████| 1636/1636 [00:00<00:00, 50141.99it/s]
# 100%|██████████| 1636/1636 [00:00<00:00, 1934.98it/s]
# train-test split
# xgBoost

# %%
## 2014-15 --rf
plot_model_coeff(rf,10,tf_idf.get_feature_names())

# %%
## 2015-16 -- rf
plot_model_coeff(rf,10,tf_idf.get_feature_names())

# %%
## 2016-17 -- rf
plot_model_coeff(rf,10,tf_idf.get_feature_names())

# %%
## 2014-15  .. not much intresting
from xgboost import plot_importance
fig, ax = plt.subplots(1,1,figsize=(10,10),)
plot_importance(xgb_model,importance_type='cover',max_num_features =10,ax=ax) 
plt.show()

# %%
# 2015-16
fig, ax = plt.subplots(1,1,figsize=(10,10))
plot_importance(xgb_model,importance_type='gain',max_num_features =20,ax=ax)
plt.show()

# %%
## 2016-17  -- getting hanged..
fontsize=10
from xgboost import plot_importance
fig, ax = plt.subplots(1,1,figsize=(10,10),)
plot_importance(xgb_model,max_num_features =10,ax=ax,importance_type='gain' )
plt.show()

# %%
# 2014-15 -- svm
util.plot_coeff(20,svm_,tfidf.get_feature_names())
# Out:
# array([ 0.28033782,  0.27798611, -0.01364001, ..., -0.03396265,
#         0.06855672,  0.06855672])

# %%
# 2015-16
util.plot_coeff(10,svm,tf_idf.get_feature_names())
# Out:
# array([-0.23134392,  0.23366771, -0.05897826, ..., -0.0895967 ,
#        -0.07892998, -0.02808024])

# %%
# 2016-17
util.plot_coeff(20,svm,tf_idf.get_feature_names())
# Out:
# array([-1.47458857,  0.02193746,  0.        , ...,  0.53290239,
#         0.02032167,  0.        ])

# %% [markdown]
# ## capture user features

# %%
svm_scores = []
rf_scores = []
xgb_scores = []
maj_scores = []
Y_tests = []
for year,data,users_labelled in bucket_data:
    print("************")
    print("preparing the data")
    train_data,test_data,Y_train, Y_test = preprocessing.prepare_data(data,users_labelled)
    all_models = driver.run_user_features(train_data, test_data, Y_train, Y_test,"over") ## oversampled data
    
    
    ## user predictions
    svm_scores.append(all_models['svm'][1])
    rf_scores.append(all_models['rf'][1])
    xgb_scores.append(all_models['xgb'][1])
    Y_tests.append(Y_test)
# Out:
#   0%|          | 0/1049 [00:00<?, ?it/s]
# 100%|██████████| 1049/1049 [00:00<00:00, 52104.08it/s]
#   0%|          | 0/1049 [00:00<?, ?it/s]
#  31%|███       | 320/1049 [00:00<00:00, 3194.42it/s]
# ************
# preparing the data
#  57%|█████▋    | 595/1049 [00:00<00:00, 3043.49it/s]
#  77%|███████▋  | 811/1049 [00:00<00:00, 2709.57it/s]
# 100%|██████████| 1049/1049 [00:00<00:00, 2635.44it/s]
# train-test split
# /home/xavlock2345/twitter_juul/src/preprocess/escalation/preprocessing.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   user_data["ff_ratio"] = user_data["followersCount"] / user_data["friendsCount"]
# /home/xavlock2345/twitter_juul/src/preprocess/escalation/preprocessing.py:56: RuntimeWarning: divide by zero encountered in log
#   "listedCount"]])
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/pandas/core/frame.py:2540: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]
# before sampling postives in train  78 total lenggth: 839
# after sampling postives in train  761 total lenggth: 1522
# training the models
# X_train shape (1522, 8)
# X_test shape (210, 8)
# svm
# [LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear]svm cross val score mean [0.68195355 0.5811003 ]
#
# random_forest
# rf cross val score mean [0.7244896  0.71061249]
#
# xgBoost
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
#
#   0%|          | 0/1636 [00:00<?, ?it/s]
# 100%|██████████| 1636/1636 [00:00<00:00, 48486.67it/s]
#   0%|          | 0/1636 [00:00<?, ?it/s]
# xgb corss val score mean [0.86529947 0.8608604 ]
#
# the best model xgb
# baseline scores calculated
# ************
# preparing the data
#  17%|█▋        | 283/1636 [00:00<00:00, 2799.96it/s]
#  25%|██▌       | 409/1636 [00:00<00:00, 2048.16it/s]
#  40%|████      | 656/1636 [00:00<00:00, 2157.61it/s]
#  55%|█████▍    | 893/1636 [00:00<00:00, 2215.90it/s]
#  68%|██████▊   | 1116/1636 [00:00<00:00, 2219.69it/s]
#  81%|████████  | 1323/1636 [00:00<00:00, 2169.22it/s]
#  93%|█████████▎| 1515/1636 [00:00<00:00, 1653.75it/s]
# 100%|██████████| 1636/1636 [00:00<00:00, 1933.68it/s]
# train-test split
# /home/xavlock2345/twitter_juul/src/preprocess/escalation/preprocessing.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   user_data["ff_ratio"] = user_data["followersCount"] / user_data["friendsCount"]
# /home/xavlock2345/twitter_juul/src/preprocess/escalation/preprocessing.py:56: RuntimeWarning: divide by zero encountered in log
#   "listedCount"]])
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/pandas/core/frame.py:2540: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]
# before sampling postives in train  207 total lenggth: 1308
# after sampling postives in train  1101 total lenggth: 2202
# training the models
# X_train shape (2202, 8)
# X_test shape (328, 8)
# svm
# [LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear]svm cross val score mean [0.68436096 0.64627141]
#
# random_forest
# rf cross val score mean [0.69387112 0.66920739]
#
# xgBoost
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# xgb corss val score mean [0.78999859 0.79464818]
#
# the best model xgb
# baseline scores calculated
# ************
# preparing the data
#   0%|          | 0/40236 [00:00<?, ?it/s]
#  17%|█▋        | 6754/40236 [00:00<00:00, 67537.65it/s]
#  34%|███▍      | 13660/40236 [00:00<00:00, 67987.23it/s]
#  52%|█████▏    | 20732/40236 [00:00<00:00, 68782.97it/s]
#  69%|██████▉   | 27943/40236 [00:00<00:00, 69745.90it/s]
#  87%|████████▋ | 34937/40236 [00:00<00:00, 69802.99it/s]
# 100%|██████████| 40236/40236 [00:00<00:00, 69505.37it/s]
#   0%|          | 0/40236 [00:00<?, ?it/s]
#   1%|          | 229/40236 [00:00<00:17, 2254.96it/s]
#   1%|          | 407/40236 [00:00<00:19, 2086.66it/s]
#   1%|▏         | 601/40236 [00:00<00:19, 2037.62it/s]
#   2%|▏         | 827/40236 [00:00<00:18, 2098.21it/s]
#   3%|▎         | 1069/40236 [00:00<00:17, 2182.34it/s]
#   3%|▎         | 1252/40236 [00:00<00:19, 2037.86it/s]
#   4%|▎         | 1445/40236 [00:00<00:19, 1994.00it/s]
#   4%|▍         | 1668/40236 [00:00<00:18, 2059.29it/s]
#   5%|▍         | 1864/40236 [00:00<00:19, 1961.06it/s]
#   5%|▌         | 2106/40236 [00:01<00:18, 2076.09it/s]
#   6%|▌         | 2320/40236 [00:01<00:18, 2094.68it/s]
#   6%|▋         | 2583/40236 [00:01<00:16, 2230.16it/s]
#   7%|▋         | 2808/40236 [00:01<00:17, 2185.39it/s]
#   8%|▊         | 3028/40236 [00:01<00:17, 2162.53it/s]
#   8%|▊         | 3302/40236 [00:01<00:16, 2303.54it/s]
#   9%|▉         | 3539/40236 [00:01<00:15, 2320.68it/s]
#   9%|▉         | 3775/40236 [00:01<00:15, 2331.92it/s]
#  10%|▉         | 4010/40236 [00:01<00:16, 2205.29it/s]
#  11%|█         | 4259/40236 [00:01<00:15, 2278.02it/s]
#  11%|█         | 4500/40236 [00:02<00:15, 2315.04it/s]
#  12%|█▏        | 4734/40236 [00:02<00:15, 2235.01it/s]
#  12%|█▏        | 4960/40236 [00:02<00:15, 2214.44it/s]
#  91%|█████████ | 36600/40236 [00:15<00:01, 2419.13it/s]
#  92%|█████████▏| 36849/40236 [00:15<00:01, 2335.74it/s]
#  92%|█████████▏| 37085/40236 [00:15<00:01, 2219.20it/s]
#  93%|█████████▎| 37327/40236 [00:16<00:01, 2275.47it/s]
#  93%|█████████▎| 37565/40236 [00:16<00:01, 2294.71it/s]
#  94%|█████████▍| 37797/40236 [00:16<00:01, 2297.67it/s]
#  95%|█████████▍| 38038/40236 [00:16<00:00, 2327.02it/s]
#  95%|█████████▌| 38272/40236 [00:16<00:00, 2260.73it/s]
#  96%|█████████▌| 38500/40236 [00:16<00:00, 2226.68it/s]
#  96%|█████████▋| 38740/40236 [00:16<00:00, 2262.38it/s]
#  97%|█████████▋| 38988/40236 [00:16<00:00, 2322.50it/s]
#  98%|█████████▊| 39252/40236 [00:16<00:00, 2406.71it/s]
#  98%|█████████▊| 39502/40236 [00:16<00:00, 2432.70it/s]
#  99%|█████████▉| 39747/40236 [00:17<00:00, 2389.27it/s]
#  99%|█████████▉| 39987/40236 [00:17<00:00, 2200.24it/s]
# 100%|██████████| 40236/40236 [00:17<00:00, 2326.44it/s]
# train-test split
# /home/xavlock2345/twitter_juul/src/preprocess/escalation/preprocessing.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   user_data["ff_ratio"] = user_data["followersCount"] / user_data["friendsCount"]
# /home/xavlock2345/twitter_juul/src/preprocess/escalation/preprocessing.py:56: RuntimeWarning: divide by zero encountered in log
#   "listedCount"]])
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/pandas/core/frame.py:2540: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]
# before sampling postives in train  7445 total lenggth: 32188
# after sampling postives in train  24743 total lenggth: 49486
# training the models
# X_train shape (49486, 8)
# X_test shape (8048, 8)
# svm
# [LibLinear][LibLinear][LibLinear][LibLinear][LibLinear][LibLinear]svm cross val score mean [0.70431981 0.64841852]
#
# random_forest
# rf cross val score mean [0.6998628  0.65864189]
#
# xgBoost
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# xgb corss val score mean [0.7082579  0.69652754]
#
# the best model xgb
# baseline scores calculated
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
## get distribution of positives in test data..
# dump_scores
import pickle
scores = {"svm_scores" : svm_scores,
               "rf_scores" : rf_scores,
               "lstm" : lstm_scores,
               "xgb" : xgb_scores}

with open(os.path.join(model_dir,"user_scores.pkl"),"wb") as f:
    pickle.dump(scores,f)

# %%
user_scores = pickle.load(open(os.path.join(model_dir,"user_scores.pkl"),"rb"))

# %%
user_scores["xgb"]
# Out:
# [array([0.86529947, 0.8608604 ]),
#  array([0.78999859, 0.79464818]),
#  array([0.7082579 , 0.69652754])]

# %%
for scores in user_scores["xgb"]:
    print(scores.mean())
# Out:
# 0.8630799355370784
# 0.7923233821683502
# 0.7023927183606827

# %% [markdown]
# ### Plotting

# %% [markdown]
# ### oversampling

# %%
from sklearn.metrics import precision_recall_fscore_support
maj_scores_neg = []
maj_scores_pos = []
for Y_test in Y_tests:
    y_pred_neg = [0 for x in range(len(Y_test))]
    y_pred_pos = [1 for x in range(len(Y_test))]
    print("length of Y_test",len(Y_test))
    print("positives in Y_test", (util.get_postives(Y_test)))
    maj_pos = precision_recall_fscore_support(Y_test,y_pred_pos,average=None)[2][0]
    maj_scores_pos.append(maj_pos)
    maj_neg = precision_recall_fscore_support(Y_test,y_pred_neg,average=None)[2][0]
    maj_scores_neg.append(maj_neg)
# Out:
# length of Y_test 210
# positives in Y_test 19
# length of Y_test 328
# positives in Y_test 52
# length of Y_test 8048
# positives in Y_test 1861
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
svm = [ele[0] for ele in svm_scores]
rf = [ele[0] for ele in rf_scores]
xgb = [ele[0] for ele in xgb_scores]
maj_score_pos = [ele for ele in maj_scores_pos]
maj_score_neg = [ele for ele in maj_scores_neg]
## plotting user features
plt.figure(figsize=(15,7))
years = ["2014-15","2015-16","2016-17"]
plt.plot(years,maj_score_pos,label="majority all change to poly")
plt.plot(years,maj_score_neg,label="majority remain mono")
plt.plot(years,svm,label="svm")
plt.plot(years,rf,label="rf")
plt.plot(years,xgb,label="xg-boost")
plt.title("Performance of classifiers for predicting mono users using User Features")
plt.ylabel("F1 score")
plt.legend()
plt.show()

# %%
svm = [ele[1] for ele in svm_scores]
rf = [ele[1] for ele in rf_scores]
xgb = [ele[1] for ele in xgb_scores]
maj_score_pos = [ele for ele in maj_scores_pos]
maj_score_neg = [ele for ele in maj_scores_neg]
## plotting user features
plt.figure(figsize=(15,7))
years = ["2014-15","2015-16","2016-17"]
plt.plot(years,maj_score_pos,label="majority all change to poly")
plt.plot(years,maj_score_neg,label="majority remain mono")
plt.plot(years,svm,label="svm")
plt.plot(years,rf,label="rf")
plt.plot(years,xgb,label="xg-boost")
plt.title("Performance of classifiers for predicting mono users using User Features")
plt.ylabel("F1 score")
plt.legend()
plt.show()

# %% [markdown]
# ### undersampling..

# %%
from sklearn.metrics import precision_recall_fscore_support
maj_scores_neg = []
maj_scores_pos = []
for Y_test in Y_tests:
    y_pred_neg = [0 for x in range(len(Y_test))]
    y_pred_pos = [1 for x in range(len(Y_test))]
    print("length of Y_test",len(Y_test))
    print("positives in Y_test", (util.get_postives(Y_test)))
    maj_pos = precision_recall_fscore_support(Y_test,y_pred_pos,average=None)[2][0]
    maj_scores_pos.append(maj_pos)
    maj_neg = precision_recall_fscore_support(Y_test,y_pred_neg,average=None)[2][0]
    maj_scores_neg.append(maj_neg)
# Out:
# length of Y_test 210
# positives in Y_test 19
# length of Y_test 328
# positives in Y_test 52
# length of Y_test 8048
# positives in Y_test 1861
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
svm = [ele[0] for ele in svm_scores]
rf = [ele[0] for ele in rf_scores]
xgb = [ele[0] for ele in xgb_scores]
maj_score_pos = [ele for ele in maj_scores_pos]
maj_score_neg = [ele for ele in maj_scores_neg]
## plotting user features
plt.figure(figsize=(15,7))
years = ["2014-15","2015-16","2016-17"]
plt.plot(years,maj_score_pos,label="majority all change to poly")
plt.plot(years,maj_score_neg,label="majority remain mono")
plt.plot(years,svm,label="svm")
plt.plot(years,rf,label="rf")
plt.plot(years,xgb,label="xg-boost")
plt.title("Performance of classifiers for predicting mono users using User Features")
plt.ylabel("F1 score")
plt.legend()
plt.show()

# %%
svm = [ele[1] for ele in svm_scores]
rf = [ele[1] for ele in rf_scores]
xgb = [ele[1] for ele in xgb_scores]
maj_score_pos = [ele for ele in maj_scores_pos]
maj_score_neg = [ele for ele in maj_scores_neg]
## plotting user features
plt.figure(figsize=(15,7))
years = ["2014-15","2015-16","2016-17"]
plt.plot(years,maj_score_pos,label="majority all change to poly")
plt.plot(years,maj_score_neg,label="majority remain mono")
plt.plot(years,svm,label="svm")
plt.plot(years,rf,label="rf")
plt.plot(years,xgb,label="xg-boost")
plt.title("Performance of classifiers for predicting mono users using User Features")
plt.ylabel("F1 score")
plt.legend()
plt.show()

# %%
## using spectral clustering
# clustering = SpectralClustering(n_clusters=100,assign_labels="discretize",random_state=0, n_init=10, n_jobs=-1).fit(X)
# ## all the words are coming into one cluster
# len(cluster_dict[0]) ## 5761

# %% [markdown]
# # combining user and text features

# %%
## using k-1 fold algorithm for calculating cross val score for ensemble model
## making predictions on kth fold and passing it to the next stage for 2nd stage ensemble

# %% [markdown]
# ## old way-- not cross validated

# %%
dimension = 100
epoch = 20
data_list = []
for year,data,users_labelled in bucket_data:
    train_data,test_data,Y_train, Y_test = preprocessing.prepare_data(data,users_labelled)
    lstm_scores, lstm_pred, lstm_model, keras_tkzr, max_len= driver.run_lstm(
                                        train_data["tweetText"],test_data["tweetText"],
                                    Y_train, Y_test,dimension,epoch,cross_splits= 2,option="over",cross_val=False)
    all_models = driver.run_user_features(train_data, test_data, Y_train, Y_test)
    
    baseline_models, tfidf, svd =  driver.run_text_features(train_data["tweetText"], test_data["tweetText"], 
                                                            Y_train, Y_test)
    
    ## predicting using the ensemble method for all text and user
        data_pred = {
#                 'svm_user': all_models["svm"][0], 
#                  'rf_user': all_models["rf"][0], 
                 "xgb_user" : all_models["xgb"][0] ,  
#                  'lstm': lstm_pred,
#                 "svm_text":baseline_models["svm"][0], 
#                  "rf_text":baseline_models["rf"][0],
                "xgb":baseline_models["xgb"][0]}
    
    ## saving the model and configs
    all_models["lstm"] = [lstm_pred,lstm_scores,lstm_model,keras_tkzr,max_len]
    all_models["svm_text"] = baseline_models["svm"]
    all_models["rf_text"] = baseline_models["rf"]
    all_models["xgb_text"] = baseline_models["xgb"]
    all_models["tfidf"] = tfidf
    all_models["svd"] = svd
    
    df_data = pd.DataFrame(data= data_pred)
    data_list.append((test_data,Y_test,df_data,all_models))
# Out:
# 100%|██████████| 1049/1049 [00:00<00:00, 56590.84it/s]
# 100%|██████████| 1049/1049 [00:00<00:00, 2669.54it/s]
# train-test split
# text_data (1904, 100) Y 1904
# user_data (1904, 8) Y 1904
# at split

# %%
ensemble_scores = []
for val_data,test_data,Y_val,Y_test,data_pred,all_models in data_list:
    
#     switching with different models
    data_pred = {
#             'svm_user': data_pred["svm_user"], 
#              'rf_user': data_pred["rf_user"], 
         "xgb_user" : data_pred["xgb_user"] ,  
    #                  'lstm': lstm_pred,
        "svm_text":  data_pred["svm_text"], 
#              "rf_text":data_pred["rf_text"],
#             "xgb_text":data_pred["xgb_text"] 
                   }
    
    df_data = pd.DataFrame(data= data_pred)
    X = df_data.values   ## all model predictions
    y = Y_val
    print("ensemble y val",X.shape)
    print("ensemble y val",len(y))
    
    ## training with validation data
    lr = LogisticRegression(random_state=0, solver='lbfgs', multi_class='multinomial').fit(X,y)
    print(lr.coef_)
    weights = lr.coef_[0]
    print(len(weights))
    #     best_idx = np.argmax(lr.coef_[0])
    ## will use the weighst to make prediction on test set

    ## unpacking all of the models
#     _,_,lstm_model,keras_tkzr,max_len = all_models["lstm"]
    _,_,svm_text = all_models["svm_text"]
    _,_,rf_text  = all_models["rf_text"] 
    _,_,xgb_text = all_models["xgb_text"] 
    _,_,svm_user = all_models["svm"]
    _,_,rf_user  = all_models["rf"]
    _,_,xgb_user = all_models["xgb"]
    tfidf = all_models["tfidf"]
    svd  = all_models["svd"] 

    ## getting predicting on test data
    ## text predictions
#     lstm_pred = lstm_module.cal_lstm_pred(test_data,lstm_model,keras_tkzr,max_len)
#     print("lstm prediction",len(lstm_pred))
    
    svm_text_pred = baselines.cal_text_pred(test_data,svm_text,tfidf,svd)
    rf_text_pred = baselines.cal_text_pred(test_data,rf_text,tfidf,svd)
    xgb_text_pred = baselines.cal_text_pred(test_data,xgb_text,tfidf,svd)
    
    ## user predictions
    svm_pred  = baselines.cal_user_pred(test_data, svm_user)
    rf_pred = baselines.cal_user_pred(test_data, rf_user)
    xgb_pred = baselines.cal_user_pred(test_data, xgb_user)
    
    
    ## predicting with test data
    ## predicting using the ensemble method
    data_pred = {
#                 "svm_user": svm_pred, 
#                  "rf_user": rf_pred, 
                 "xgb_user" : xgb_pred ,
#                  "lstm": lstm_pred , 
#                  "svm_text": svm_text_pred,
#                  "rf_text":rf_text_pred,
#                  "xgb_text":xgb_text_pred,               
                      }
    print("data pred length", len(data_pred))
    df_pred = pd.DataFrame(data= data_pred)
    print("pred shape",df_pred.shape)
    
    # weighted idea
    df_pred = df_pred.mul(list(weights))
    pred = list(df_pred.sum(axis=1))  # weighted ensemble
    final_pred = [1 if p >= 0.5 else 0 for p in pred ]  ## threshold as 0.5

    #      majority voting , simple..
#     df_pred["pred"] = df_pred.sum(axis=1)
#     pred = list(df_pred["pred"])
#     final_pred = [1 if p == 2 else 0 for p in pred] ## simple amjority 
    
#     df_data["pred"] = df_data.iloc[:,best_idx]  ## selecting based on max weight
#     print("best index = ",best_idx)
#     final_pred = list(df_data["pred"])
    
    
    print('  Classification Report ensemble:\n',classification_report(Y_test,xgb_pred),'\n')
    ensemble_score = precision_recall_fscore_support(Y_test,final_pred,average=None)[2]
    ensemble_scores.append(ensemble_score)
# Out:
# ensemble y val (210, 1)
# ensemble y val 210
# [[0.6653179]]
# 1
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# data pred length 1
# pred shape (210, 1)
#   Classification Report ensemble:
#               precision    recall  f1-score   support
#
#           0       0.94      0.83      0.88       191
#           1       0.22      0.47      0.30        19
#
# avg / total       0.88      0.80      0.83       210
#
#
# ensemble y val (327, 1)
# ensemble y val 327
# [[0.64961953]]
# 1
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# data pred length 1
# pred shape (328, 1)
#   Classification Report ensemble:
#               precision    recall  f1-score   support
#
#           0       0.89      0.77      0.83       276
#           1       0.30      0.52      0.38        52
#
# avg / total       0.80      0.73      0.76       328
#
#
# ensemble y val (8047, 1)
# ensemble y val 8047
# [[0.8672755]]
# 1
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# data pred length 1
# pred shape (8048, 1)
#   Classification Report ensemble:
#               precision    recall  f1-score   support
#
#           0       0.87      0.72      0.79      6187
#           1       0.42      0.65      0.51      1861
#
# avg / total       0.77      0.71      0.73      8048
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %% [markdown]
# # new ensemble way -- cross validated

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_recall_fscore_support
from sklearn.svm import LinearSVC
from xgboost import XGBClassifier
def get_baseline_models():
    svm = LinearSVC(C=1, verbose=1)
    rf = RandomForestClassifier(n_estimators=100, max_depth=2,
                                random_state=0)
    xgb = XGBClassifier()
    
    models = {
        "svm":svm,
        "rf":rf,
        "xgb":xgb
                 }
    return models

# %%
def get_cross_val_pred(model,X,Y,n_splits):
    y_preds = []
    for train, test in kFold.split(X, Y):
        model.fit(X[train], Y[train])
        y_preds.append(model.predict(X[test]))
    return y_preds

# %%
# Algorithm
# Split the train set in k folds
# Fit a first stage model on k-1 folds and predict the kth fold
# Repeat 2) to predict each fold

## preparing the data
from sklearn.model_selection import train_test_split
from sklearn.decomposition import TruncatedSVD
from sklearn.feature_extraction.text import TfidfVectorizer
dimension = 100
epoch = 20
k_splits = 5
data_list = []
kFold = StratifiedKFold(n_splits=k_splits)
svd = TruncatedSVD(n_components=100, n_iter=7, random_state=42)
tf_idf = TfidfVectorizer(sublinear_tf=True)
df_pred_final = []
for year,data,users_labelled in bucket_data:
    train_data,test_data,Y_train, Y_test = preprocessing.prepare_data(data,users_labelled)
    
    ## using k-fold so combine the data
    total_data = train_data.append(test_data)
    total_data = total_data.reset_index(drop=True)
    Y = np.array(list(Y_train) + list(Y_test))
    
    ## vectorize the text
    tf_idf.fit(total_data["tweetText"])  ## fit on train data
    temp_data = tf_idf.transform(total_data["tweetText"])
    svd.fit(temp_data)
    temp_data = (svd.transform(temp_data))
    text_data,Y_text = util.get_oversample(temp_data,Y)
    
    user_feat,_ = preprocessing.prepare_user_features(total_data)
    user_data,Y_user = util.get_oversample(user_feat,Y)
    
    print("text_data",text_data.shape,"Y",len(Y_text))
    print("user_data",user_data.shape,"Y",len(Y_user))
    
    ## combining all of user and text data
    final_data = pd.DataFrame(user_data)
    final_data["tweetText"] = list(text_data)
    Y_final = Y_text
    
    df_pred_temp = pd.DataFrame()
    for split,(train_ind,test_ind) in enumerate(kFold.split(final_data.index,Y_final)):
        print("at split",split)
        train_data = final_data.iloc[train_ind]
        test_data = final_data.iloc[test_ind]
        
        Y_train = Y_final[train_ind]
        Y_test =  Y_final[test_ind]
        
        X_train_user = train_data.loc[:, train_data.columns != "tweetText"]
        X_test_user = test_data.loc[:, train_data.columns != "tweetText"]
        X_train_text = np.array(list(train_data["tweetText"]))
        X_test_text = np.array(list(test_data["tweetText"]))
        
        models = get_baseline_models()
        df_pred = {}
        for name,model in models.items(): 
            model.fit(X_train_user,Y_train)
            pred1 = model.predict(X_test_user)
            df_pred[(name+"_user")]  = list(pred1) 
            print(name,"user Classification report \n",classification_report(pred1,Y_test))
            
            model.fit(X_train_text,Y_train)
            pred2  = model.predict(X_test_text)
            df_pred[name+"_text"] = list(pred2) 
            print(name,"text Classification report\n",classification_report(pred2,Y_test))
        df_pred["Y"] = list(Y_test)
        temp = pd.DataFrame.from_dict(df_pred,orient="columns")
        df_pred_temp = df_pred_temp.append(temp)
    df_pred_final.append(df_pred_temp)
# Out:
#   0%|          | 0/1049 [00:00<?, ?it/s]
# 100%|██████████| 1049/1049 [00:00<00:00, 57232.01it/s]
#   0%|          | 0/1049 [00:00<?, ?it/s]
#  30%|███       | 319/1049 [00:00<00:00, 3189.52it/s]
#  58%|█████▊    | 604/1049 [00:00<00:00, 3077.82it/s]
#  78%|███████▊  | 816/1049 [00:00<00:00, 2706.49it/s]
# 100%|██████████| 1049/1049 [00:00<00:00, 2672.87it/s]
# train-test split
# text_data (1904, 100) Y 1904
# user_data (1904, 8) Y 1904
# at split 0
# [LibLinear]svm user Classification report
#               precision    recall  f1-score   support
#
#           0       0.65      0.69      0.67       180
#           1       0.71      0.67      0.69       202
#
# avg / total       0.68      0.68      0.68       382
#
# [LibLinear]svm text Classification report
#               precision    recall  f1-score   support
#
#           0       0.70      0.72      0.71       186
#           1       0.72      0.70      0.71       196
#
# avg / total       0.71      0.71      0.71       382
#
# rf user Classification report
#               precision    recall  f1-score   support
#
#           0       0.62      0.77      0.69       155
#           1       0.81      0.68      0.74       227
#
# avg / total       0.74      0.72      0.72       382
#
# rf text Classification report
#               precision    recall  f1-score   support
#
#           0       0.70      0.73      0.71       182
#           1       0.74      0.71      0.73       200
#
# avg / total       0.72      0.72      0.72       382
#
# xgb user Classification report
#               precision    recall  f1-score   support
#
#           0       0
# xgb text Classification report
#               precision    recall  f1-score   support
#
#           0       0.97      0.93      0.95       197
#           1       0.93      0.97      0.95       183
#
# avg / total       0.95      0.95      0.95       380
#  17%|█▋        | 273/1636 [00:00<00:00, 2729.19it/s]
#  24%|██▍       | 396/1636 [00:00<00:00, 1997.84it/s]
#  40%|███▉      | 647/1636 [00:00<00:00, 2127.74it/s]
#  54%|█████▍    | 886/1636 [00:00<00:00, 2198.27it/s]
#  68%|██████▊   | 1106/1636 [00:00<00:00, 2197.90it/s]
#  81%|████████  | 1318/1636 [00:00<00:00, 2165.27it/s]
#  92%|█████████▏| 1511/1636 [00:00<00:00, 1658.67it/s]
# 100%|██████████| 1636/1636 [00:00<00:00, 1928.04it/s]
# train-test split
# /home/xavlock2345/twitter_juul/src/preprocess/escalation/preprocessing.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   user_data["ff_ratio"] = user_data["followersCount"] / user_data["friendsCount"]
# /home/xavlock2345/twitter_juul/src/preprocess/escalation/preprocessing.py:56: RuntimeWarning: divide by zero encountered in log
#   "listedCount"]])
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/pandas/core/frame.py:2540: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]
# text_data (2754, 100) Y 2754
# user_data (2754, 8) Y 2754
# at split 0
# [LibLinear]svm user Classification report
#               precision    recall  f1-score   support
#
#           0       0.68      0.75      0.71       249
#           1       0.78      0.71      0.74       303
#
# avg / total       0.73      0.73      0.73       552
#
# [LibLinear]svm text Classification report
#               precision    recall  f1-score   support
#
#           0       0.78      0.71      0.74       303
#           1       0.68      0.75      0.71       249
#
# avg / total       0.73      0.73      0.73       552
#
# rf user Classification report
#               precision    recall  f1-score   support
#
#           0       0.71      0.73      0.72       270
#           1       0.73      0.72      0.72       282
#
# avg / total       0.72      0.72      0.72       552
#
# rf text Classification report
#               precision    recall  f1-score   support
#
#           0       0.74      0.70      0.72       293
#           1       0.68      0.72      0.70       259
#
# avg / total       0.71      0.71      0.71       552
#
# xgb user Classification report
#               precision    recall  f1-score   support
#
#           0       0.76      0.90      0.82       233
#           1       0.91      0.79      0.85       319
#
# avg / total       0.85      0.84      0.84       552
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# xgb text Classification report
#               precision    recall  f1-score   support
#
#           0       0.85      0.94      0.89       248
#           1       0.95      0.86      0.90       304
#
# avg / total       0.90      0.90      0.90       552
#
# at split 1
# [LibLinear]svm user Classification report
#               precision    recall  f1-score   support
#
#           0       0.54      0.68      0.60       218
#           1       0.75      0.62      0.68       334
#
# avg / total       0.67      0.64      0.65       552
#
# [LibLinear]svm text Classification report
#               precision    recall  f1-score   support
#
#           0       0.71      0.76      0.74       257
#           1       0.78      0.73      0.75       295
#
# avg / total       0.75      0.74      0.74       552
#
# rf user Classification report
#               precision    recall  f1-score   support
#
#           0       0.73      0.73      0.73       278
#           1       0.72      0.73      0.73       274
#
# avg / total       0.73      0.73      0.73       552
#
# rf text Classification report
#               precision    recall  f1-score   support
#
#           0       0.72      0.69      0.71       287
#           1       0.68      0.71      0.70       265
#
# avg / total       0.70      0.70      0.70       552
#
# xgb user Classification report
#               precision    recall  f1-score   support
#
#           0       0.69      0.91      0.79       210
#           1       0.93      0.75      0.83       342
#
# avg / total       0.84      0.81      0.81       552
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# xgb text Classification report
#               precision    recall  f1-score   support
#
#           0       0.82      0.94      0.88       242
#           1       0.95      0.84      0.89       310
#
# avg / total       0.89      0.88      0.88       552
#
# at split 2
# [LibLinear]svm user Classification report
#               precision    recall  f1-score   support
#
#           0       0.56      0.72      0.63       214
#           1       0.79      0.64      0.71       336
#
# avg / total       0.70      0.67      0.68       550
#
# [LibLinear]svm text Classification report
#               precision    recall  f1-score   support
#
#           0       0.71      0.67      0.69       292
#           1       0.65      0.69      0.67       258
#
# avg / total       0.68      0.68      0.68       550
#
# rf user Classification report
#               precision    recall  f1-score   support
#
#           0       0.64      0.74      0.69       240
#           1       0.77      0.68      0.72       310
#
# avg / total       0.72      0.71      0.71       550
#
# rf text Classification report
#               precision    recall  f1-score   support
#
#           0       0.72      0.65      0.69       306
#           1       0.61      0.69      0.65       244
#
# avg / total       0.67      0.67      0.67       550
#
# xgb user Classification report
#               precision    recall  f1-score   support
#
#           0       0.73      0.89      0.80       228
#           1       0.91      0.77      0.83       322
#
# avg / total       0.83      0.82      0.82       550
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# xgb text Classification report
#               precision    recall  f1-score   support
#
#           0       0.84      0.92      0.87       251
#           1       0.92      0.85      0.89       299
#
# avg / total       0.88      0.88      0.88       550
#
# at split 3
# [LibLinear]svm user Classification report
#               precision    recall  f1-score   support
#
#           0       0.57      0.71      0.63       220
#           1       0.77      0.64      0.70       330
#
# avg / total       0.69      0.67      0.67       550
#
# [LibLinear]svm text Classification report
#               precision    recall  f1-score   support
#
#           0       0.71      0.69      0.70       281
#           1       0.68      0.70      0.69       269
#
# avg / total       0.69      0.69      0.69       550
#
# rf user Classification report
#               precision    recall  f1-score   support
#
#           0       0
#  90%|█████████ | 36218/40236 [00:15<00:01, 2193.47it/s]
#  91%|█████████ | 36482/40236 [00:15<00:01, 2310.35it/s]
#  91%|█████████▏| 36751/40236 [00:15<00:01, 2409.71it/s]
#  92%|█████████▏| 36996/40236 [00:15<00:01, 2259.51it/s]
#  93%|█████████▎| 37227/40236 [00:16<00:01, 2214.67it/s]
#  93%|█████████▎| 37455/40236 [00:16<00:01, 2230.71it/s]
#  94%|█████████▎| 37681/40236 [00:16<00:01, 2211.91it/s]
#  94%|█████████▍| 37934/40236 [00:16<00:01, 2296.27it/s]
#  95%|█████████▍| 38166/40236 [00:16<00:00, 2235.12it/s]
#  95%|█████████▌| 38405/40236 [00:16<00:00, 2275.68it/s]
#  96%|█████████▌| 38634/40236 [00:16<00:00, 2253.40it/s]
#  97%|█████████▋| 38865/40236 [00:16<00:00, 2269.53it/s]
#  97%|█████████▋| 39093/40236 [00:16<00:00, 2253.03it/s]
#  98%|█████████▊| 39355/40236 [00:17<00:00, 2351.27it/s]
#  98%|█████████▊| 39592/40236 [00:17<00:00, 2262.40it/s]
#  99%|█████████▉| 39821/40236 [00:17<00:00, 2256.58it/s]
# 100%|█████████▉| 40048/40236 [00:17<00:00, 2209.32it/s]
# 100%|██████████| 40236/40236 [00:17<00:00, 2309.85it/s]
# train-test split
# /home/xavlock2345/twitter_juul/src/preprocess/escalation/preprocessing.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   user_data["ff_ratio"] = user_data["followersCount"] / user_data["friendsCount"]
# /home/xavlock2345/twitter_juul/src/preprocess/escalation/preprocessing.py:56: RuntimeWarning: divide by zero encountered in log
#   "listedCount"]])
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/pandas/core/frame.py:2540: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]
# text_data (61860, 100) Y 61860
# user_data (61860, 8) Y 61860
# at split 0
# [LibLinear]svm user Classification report
#               precision    recall  f1-score   support
#
#           0       0.67      0.68      0.67      6090
#           1       0.68      0.67      0.68      6282
#
# avg / total       0.67      0.67      0.67     12372
#
# [LibLinear]svm text Classification report
#               precision    recall  f1-score   support
#
#           0       0.76      0.64      0.70      7381
#           1       0.57      0.71      0.63      4991
#
# avg / total       0.69      0.67      0.67     12372
#
# rf user Classification report
#               precision    recall  f1-score   support
#
#           0       0.67      0.70      0.68      5968
#           1       0.71      0.68      0.70      6404
#
# avg / total       0.69      0.69      0.69     12372
#
# rf text Classification report
#               precision    recall  f1-score   support
#
#           0       0.67      0.64      0.66      6510
#           1       0.62      0.66      0.64      5862
#
# avg / total       0.65      0.65      0.65     12372
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# xgb user Classification report
#               precision    recall  f1-score   support
#
#           0       0.65      0.73      0.69      5544
#           1       0.76      0.69      0.72      6828
#
# avg / total       0.71      0.70      0.71     12372
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# xgb text Classification report
#               precision    recall  f1-score   support
#
#           0       0.72      0.68      0.70      6528
#           1       0.66      0.70      0.68      5844
#
# avg / total       0.69      0.69      0.69     12372
#
# at split 1
# [LibLinear]svm user Classification report
#               precision    recall  f1-score   support
#
#           0       0.67      0.67      0.67      6181
#           1       0.67      0.67      0.67      6191
#
# avg / total       0.67      0.67      0.67     12372
#
# [LibLinear]svm text Classification report
#               precision    recall  f1-score   support
#
#           0       0.75      0.63      0.69      7341
#           1       0.57      0.70      0.62      5031
#
# avg / total       0.68      0.66      0.66     12372
#
# rf user Classification report
#               precision    recall  f1-score   support
#
#           0       0.67      0.69      0.68      5929
#           1       0.71      0.68      0.69      6443
#
# avg / total       0.69      0.69      0.69     12372
#
# rf text Classification report
#               precision    recall  f1-score   support
#
#           0       0.67      0.63      0.65      6489
#           1       0.62      0.65      0.63      5883
#
# avg / total       0.64      0.64      0.64     12372
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# xgb user Classification report
#               precision    recall  f1-score   support
#
#           0       0.67      0.73      0.70      5736
#           1       0.75      0.70      0.72      6636
#
# avg / total       0.71      0.71      0.71     12372
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# xgb text Classification report
#               precision    recall  f1-score   support
#
#           0       0.71      0.67      0.69      6501
#           1       0.65      0.69      0.67      5871
#
# avg / total       0.68      0.68      0.68     12372
#
# at split 2
# [LibLinear]svm user Classification report
#               precision    recall  f1-score   support
#
#           0       0.68      0.67      0.68      6234
#           1       0.67      0.68      0.67      6138
#
# avg / total       0.67      0.67      0.67     12372
#
# [LibLinear]svm text Classification report
#               precision    recall  f1-score   support
#
#           0       0.77      0.64      0.70      7457
#           1       0.57      0.71      0.63      4915
#
# avg / total       0.69      0.67      0.67     12372
#
# rf user Classification report
#               precision    recall  f1-score   support
#
#           0       0.69      0.70      0.69      6107
#           1       0.70      0.69      0.70      6265
#
# avg / total       0.69      0.69      0.69     12372
#
# rf text Classification report
#               precision    recall  f1-score   support
#
#           0       0.66      0.64      0.65      6353
#           1       0.63      0.65      0.64      6019
#
# avg / total       0.64      0.64      0.64     12372
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# xgb user Classification report
#               precision    recall  f1-score   support
#
#           0       0.67      0.73      0.70      5657
#           1       0.76      0.70      0.72      6715
#
# avg / total       0.72      0.71      0.71     12372
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# xgb text Classification report
#               precision    recall  f1-score   support
#
#           0       0.71      0.67      0.69      6492
#           1       0.66      0.69      0.68      5880
#
# avg / total       0.68      0.68      0.68     12372
#
# at split 3
# [LibLinear]svm user Classification report
#               precision    recall  f1-score   support
#
#           0       0.67      0.67      0.67      6128
#           1       0.68      0.67      0.67      6244
#
# avg / total       0.67      0.67      0.67     12372
#
# [LibLinear]svm text Classification report
#               precision    recall  f1-score   support
#
#           0       0.76      0.64      0.69      7360
#           1       0.57      0.70      0.63      5012
#
# avg / total       0.68      0.66      0.67     12372
#
# rf user Classification report
#               precision    recall  f1-score   support
#
#           0       0.67      0.70      0.68      5930
#           1       0.71      0.68      0.69      6442
#
# avg / total       0.69      0.69      0.69     12372
#
# rf text Classification report
#               precision    recall  f1-score   support
#
#           0       0.66      0.64      0.65      6440
#           1       0.62      0.65      0.63      5932
#
# avg / total       0.64      0.64      0.64     12372
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# xgb user Classification report
#               precision    recall  f1-score   support
#
#           0       0.66      0.72      0.69      5670
#           1       0.75      0.69      0.72      6702
#
# avg / total       0.71      0.70      0.71     12372
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# xgb text Classification report
#               precision    recall  f1-score   support
#
#           0       0.71      0.67      0.69      6500
#           1       0.66      0.69      0.68      5872
#
# avg / total       0.68      0.68      0.68     12372
#
# at split 4
# [LibLinear]svm user Classification report
#               precision    recall  f1-score   support
#
#           0       0.67      0.68      0.68      6099
#           1       0.69      0.68      0.68      6273
#
# avg / total       0.68      0.68      0.68     12372
#
# [LibLinear]svm text Classification report
#               precision    recall  f1-score   support
#
#           0       0.76      0.64      0.70      7332
#           1       0.58      0.71      0.63      5040
#
# avg / total       0.69      0.67      0.67     12372
#
# rf user Classification report
#               precision    recall  f1-score   support
#
#           0       0.67      0.71      0.69      5858
#           1       0.72      0.69      0.70      6514
#
# avg / total       0.70      0.69      0.70     12372
#
# rf text Classification report
#               precision    recall  f1-score   support
#
#           0       0.65      0.64      0.65      6340
#           1       0.63      0.65      0.64      6032
#
# avg / total       0.64      0.64      0.64     12372
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# xgb user Classification report
#               precision    recall  f1-score   support
#
#           0       0.66      0.74      0.70      5526
#           1       0.77      0.69      0.73      6846
#
# avg / total       0.72      0.71      0.71     12372
#
# xgb text Classification report
#               precision    recall  f1-score   support
#
#           0       0.70      0.68      0.69      6358
#           1       0.67      0.69      0.68      6014
#
# avg / total       0.69      0.69      0.69     12372
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
## get distribution of positives in test data..
# dump_scores
import pickle
# with open(os.path.join(model_dir,"ensemble_data.pkl"),"wb") as f:
#     pickle.dump(data_list,f)

# %%
ensemble_scores_over = pickle.load(open(os.path.join(model_dir,"ensemble_scores_over.pkl"),"rb"))

# %%
ensemble_scores_maj = pickle.load(open(os.path.join(model_dir,"ensemble_scores_maj.pkl"),"rb"))

# %% [markdown]
# ### Applying ensembling

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import precision_recall_fscore_
#  89%|████████▊ | 35684/40236 [00:15<00:02, 2211.43it/s]
#  89%|████████▉ | 35924/40236 [00:15<00:01, 2250.81it/s]
#  90%|████████▉ | 36151/40236 [00:15<00:01, 2204.10it/s]
#  90%|█████████ | 36401/40236 [00:15<00:01, 2284.26it/s]
#  91%|█████████ | 36664/40236 [00:15<00:01, 2356.49it/s]
#  92%|█████████▏| 36902/40236 [00:15<00:01, 2247.80it/s]
#  92%|█████████▏| 37130/40236 [00:15<00:01, 2176.76it/s]
#  93%|█████████▎| 37350/40236 [00:16<00:01, 2154.64it/s]
#  93%|█████████▎| 37572/40236 [00:16<00:01, 2173.64it/s]
#  94%|█████████▍| 37796/40236 [00:16<00:01, 2193.11it/s]
#  95%|█████████▍| 38034/40236 [00:16<00:00, 2240.17it/s]
#  95%|█████████▌| 38259/40236 [00:16<00:00, 2169.51it/s]
#  96%|█████████▌| 38478/40236 [00:16<00:00, 2164.07it/s]
#  96%|█████████▌| 38717/40236 [00:16<00:00, 2225.65it/s]
#  97%|█████████▋| 38943/40236 [00:16<00:00, 2235.66it/s]
#  97%|█████████▋| 39205/40236 [00:16<00:00, 2336.27it/s]
#  98%|█████████▊| 39462/40236 [00:17<00:00, 2392.57it/s]
#  99%|█████████▊| 39703/40236 [00:17<00:00, 2311.80it/s]
#  99%|█████████▉| 39936/40236 [00:17<00:00, 2253.70it/s]
# 100%|█████████▉| 40163/40236 [00:17<00:00, 2220.14it/s]
# 100%|██████████| 40236/40236 [00:17<00:00, 2317.09it/s]
# train-test split

# %%
from sklearn.metrics import precision_recall_fscore_support
maj_scores_neg = []
maj_scores_pos = []
for Y_test in Y_tests:
    y_pred_neg = [0 for x in range(len(Y_test))]
    y_pred_pos = [1 for x in range(len(Y_test))]
    print("length of Y_test",len(Y_test))
    print("positives in Y_test", (util.get_postives(Y_test)))
    maj_pos = precision_recall_fscore_support(Y_test,y_pred_pos,average=None)[2][0]
    maj_scores_pos.append(maj_pos)
    maj_neg = precision_recall_fscore_support(Y_test,y_pred_neg,average=None)[2][0]
    maj_scores_neg.append(maj_neg)
# Out:
# length of Y_test 210
# positives in Y_test 19
# length of Y_test 328
# positives in Y_test 52
# length of Y_test 8048
# positives in Y_test 1861
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
def get_cross_val1(model, X, Y, n_splits):
    kFold = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=None)
    scores = []
    for train, test in kFold.split(X, Y):
        model.fit(X[train], Y[train])
        y_pred = model.predict(X[test])
        scores.append(precision_recall_fscore_support(Y[test], y_pred, average=None)[2])
    score1 = np.mean([ele[0] for ele in scores])  ## average of 5 folds
    score2 = np.mean([ele[1] for ele in scores])  ## average of 5 folds
    return np.array([score1, score2])

# %%
## using xg boost for 2nd level

# We now have the (out-of-folds) prediction of the k folds
# Split these out-of folds predictions in p folds
# Fit a second stage (stacker) model on p-1 folds and predict the pth fold
# Repeat 6) to predict each fold
p_splits = 4
ensemble_scores = []
# xgb= XGBClassifier()
# svm = LinearSVC(C=1, verbose=1)
rf = RandomForestClassifier(n_estimators=100, max_depth=2,
                           random_state=0)
for data in df_pred_final:
    Y = data["Y"]
    X = data.loc[:,data.columns != "Y"].values
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.20, random_state=4,
                                                              shuffle=True,
                                                             stratify=Y)
    rf.fit(X_train,Y_train)
    y_pred = rf.predict(X_test)
    print("classsfication report \n",classification_report(y_pred,Y_test))
    ensemble_score = precision_recall_fscore_support(y_pred,Y_test,average=None)[2]
    ensemble_scores.append(ensemble_score)
    
#     print(X.shape)
#     print(X)
#     scores = get_cross_val1(svm, X, Y, p_splits)
#     print(scores)
# Out:
# classsfication report
#               precision    recall  f1-score   support
#
#           0       0.96      0.94      0.95       196
#           1       0.94      0.96      0.95       185
#
# avg / total       0.95      0.95      0.95       381
#
# classsfication report
#               precision    recall  f1-score   support
#
#           0       0.83      0.88      0.85       261
#           1       0.88      0.84      0.86       290
#
# avg / total       0.86      0.86      0.86       551
#
# classsfication report
#               precision    recall  f1-score   support
#
#           0       0.66      0.73      0.69      5598
#           1       0.76      0.69      0.72      6774
#
# avg / total       0.71      0.71      0.71     12372

# %%
## xgboost
ensemble_scores
# Out:
# [array([0.94845361, 0.94652406]),
#  array([0.86876155, 0.87344029]),
#  array([0.69674694, 0.72197692])]

# %%
## svm
ensemble_scores
# Out:
# [array([0.94871795, 0.94623656]),
#  array([0.86705202, 0.88164666]),
#  array([0.70266272, 0.71230916])]

# %%
## random forest
ensemble_scores
# Out:
# [array([0.95090439, 0.94933333]),
#  array([0.85288641, 0.86017699]),
#  array([0.69382213, 0.72160494])]

# %%
## get distribution of positives in test data..
# dump_scores
import pickle
# with open(os.path.join(model_dir,"ensemble_scores_maj.pkl"),"wb") as f:
#     pickle.dump(ensemble_scores,f)
    
# with open(os.path.join(model_dir,"maj_Scores.pkl"),"wb") as f:
#     pickle.dump(maj_scores,f)
    
print("bufeer will not print")
# Out:
# bufeer will not print

# %% [markdown]
# ## using 2 stage meta classfier

# %% [markdown]
# ### xgb

# %%
ensemble = [ele[0] for ele in ensemble_scores]
maj_score_pos = [ele for ele in maj_scores_pos]
maj_score_neg = [ele for ele in maj_scores_neg]
## plotting user features
plt.figure(figsize=(15,7))
years = ["2014-15","2015-16","2016-17"]
# plt.plot(years,maj_score_pos,label="majority classfier")
plt.plot(years,maj_score_neg,label="majority classfier")
plt.plot(years,ensemble,label="ensemble")
plt.title("Performance of ensemble model at each interval")
plt.ylabel("F1 score")
plt.legend()
plt.show()

# %%
ensemble = [ele[1] for ele in ensemble_scores]
maj_score_pos = [ele for ele in maj_scores_pos]
maj_score_neg = [ele for ele in maj_scores_neg]
## plotting user features
plt.figure(figsize=(15,7))
years = ["2014-15","2015-16","2016-17"]
plt.plot(years,maj_score_pos,label="majority classfier")
# plt.plot(years,maj_score_neg,label="majority classfier")
plt.plot(years,ensemble,label="ensemble")
plt.title("Performance of ensemble model at each interval")
plt.ylabel("F1 score")
plt.legend()
plt.show()

# %% [markdown]
# ## svm

# %%
ensemble = [ele[0] for ele in ensemble_scores]
maj_score_pos = [ele for ele in maj_scores_pos]
maj_score_neg = [ele for ele in maj_scores_neg]
## plotting user features
plt.figure(figsize=(15,7))
years = ["2014-15","2015-16","2016-17"]
# plt.plot(years,maj_score_pos,label="majority classfier")
plt.plot(years,maj_score_neg,label="majority classfier")
plt.plot(years,ensemble,label="ensemble")
plt.title("Performance of ensemble model at each interval")
plt.ylabel("F1 score")
plt.legend()
plt.show()

# %%
ensemble = [ele[1] for ele in ensemble_scores]
maj_score_pos = [ele for ele in maj_scores_pos]
maj_score_neg = [ele for ele in maj_scores_neg]
## plotting user features
plt.figure(figsize=(15,7))
years = ["2014-15","2015-16","2016-17"]
plt.plot(years,maj_score_pos,label="majority classfier")
# plt.plot(years,maj_score_neg,label="majority classfier")
plt.plot(years,ensemble,label="ensemble")
plt.title("Performance of ensemble model at each interval")
plt.ylabel("F1 score")
plt.legend()
plt.show()

# %% [markdown]
# #### rf

# %%
ensemble = [ele[0] for ele in ensemble_scores]
maj_score_pos = [ele for ele in maj_scores_pos]
maj_score_neg = [ele for ele in maj_scores_neg]
## plotting user features
plt.figure(figsize=(15,7))
years = ["2014-15","2015-16","2016-17"]
# plt.plot(years,maj_score_pos,label="majority classfier")
plt.plot(years,maj_score_neg,label="majority classfier")
plt.plot(years,ensemble,label="ensemble")
plt.title("Performance of ensemble model at each interval")
plt.ylabel("F1 score")
plt.legend()
plt.show()

# %%
ensemble = [ele[1] for ele in ensemble_scores]
maj_score_pos = [ele for ele in maj_scores_pos]
maj_score_neg = [ele for ele in maj_scores_neg]
## plotting user features
plt.figure(figsize=(15,7))
years = ["2014-15","2015-16","2016-17"]
plt.plot(years,maj_score_pos,label="majority classfier")
# plt.plot(years,maj_score_neg,label="majority classfier")
plt.plot(years,ensemble,label="ensemble")
plt.title("Performance of ensemble model at each interval")
plt.ylabel("F1 score")
plt.legend()
plt.show()

# %% [markdown]
# ## logistic regression

# %%
ensemble_scores = pickle.load(open(os.path.join(model_dir,"ensemble_scores_over.pkl"),"rb"))

# %%
ensemble = [ele[0] for ele in ensemble_scores]
maj_score_pos = [ele for ele in maj_scores_pos]
maj_score_neg = [ele for ele in maj_scores_neg]
## plotting user features
plt.figure(figsize=(15,7))
years = ["2014-15","2015-16","2016-17"]
# plt.plot(years,maj_score_pos,label="majority classfier")
plt.plot(years,maj_score_neg,label="majority classfier")
plt.plot(years,ensemble,label="ensemble")
plt.title("Performance of ensemble model at each interval")
plt.ylabel("F1 score")
plt.legend()
plt.show()

# %%
ensemble = [ele[1] for ele in ensemble_scores]
maj_score_pos = [ele for ele in maj_scores_pos]
maj_score_neg = [ele for ele in maj_scores_neg]
## plotting user features
plt.figure(figsize=(15,7))
years = ["2014-15","2015-16","2016-17"]
plt.plot(years,maj_score_pos,label="majority classfier")
# plt.plot(years,maj_score_neg,label="majority classfier")
plt.plot(years,ensemble,label="ensemble")
plt.title("Performance of ensemble model at each interval")
plt.ylabel("F1 score")
plt.legend()
plt.show()

# %% [markdown]
# ## majority voting

# %%
ensemble_scores = pickle.load(open(os.path.join(model_dir,"ensemble_scores_maj.pkl"),"rb"))

# %%
ensemble_scores
# Out:
# [array([0.93814433, 0.25      ]),
#  array([0.8540146 , 0.25925926]),
#  array([0.82874491, 0.49447582])]

# %%
for scores

# %%
## majority voting
ensemble = [ele[0] for ele in ensemble_scores]
maj_score_pos = [ele for ele in maj_scores_pos]
maj_score_neg = [ele for ele in maj_scores_neg]
## plotting user features
plt.figure(figsize=(15,7))
years = ["2014-15","2015-16","2016-17",]
plt.plot(years,maj_score_pos,label="majority all change to poly")
plt.plot(years,maj_score_neg,label="majority remain mono")
plt.plot(years,ensemble,label="ensemble")
plt.title("Performance of ensemble model at each interval")
plt.ylabel("F1 score")
plt.legend()
plt.show()

# %%
ensemble = [ele[1] for ele in ensemble_scores]
maj_score_pos = [ele for ele in maj_scores_pos]
maj_score_neg = [ele for ele in maj_scores_neg]
## plotting user features
plt.figure(figsize=(15,7))
years = ["2014-15","2015-16","2016-17"]
plt.plot(years,maj_score_pos,label="majority all change to poly")
plt.plot(years,maj_score_neg,label="majority remain mono")
plt.plot(years,ensemble,label="ensemble")
plt.title("Performance of ensemble model at each interval")
plt.ylabel("F1 score")
plt.legend()
plt.show()

# %%
## feature importance for each of the feature
import matplotlib.pyplot as plt
plt.title("feature importance of each of the user features")
print(xgb.feature_importances_)
# plot
plt.figure(figsize=(15,4))
plt.bar(df_test.columns, xgb.feature_importances_)
plt.xticks(rotation='30',ha='right',fontsize=17)
plt.show()
# Out:
# [0.53485125 0.04940957 0.08564474 0.06018534 0.08759014 0.07345726
#  0.06082027 0.04804144]

# %% [markdown]
# ## Sequential prediction using LSTM and baseline classfier for 2018 data

# %% [markdown]
# ## Month level

# %%
## sequence of tweets for user
## output prediction would be for the users so teh lstm layer would need to flatten to a single user..

## poly_turned : if users tweets weed after september (>=9 months) 
## remain_mono :
## seeing the data in different buckets:
#   1  [jan - mar )
#   2  [mar- may )
#   3  [May - july]
#   4  [July - sept]

## use lstm
## use svm
## majority
## xg boost

# %%
import util
import driver
import preprocessing
import lstm as lstm_module
import baselines
import pickle
import matplotlib.pyplot as plt

# %%
## so we are taking the users that start on Jan 2018 and change in the month of september, 
# and we change the threshold of input data to see how accurately we can predict that

# %%
## input data :juul_data 
juul_data = pd.read_csv(os.path.join(input_dir,"juul_data.csv"),lineterminator="\n")
juul_data["tweetCreatedAt"] = pd.to_datetime(juul_data["tweetCreatedAt"])
juul_data = juul_data.loc[juul_data.userID.isin(regular_users)]

# ## look at the weed first and juul_first tweet
first_data = pd.read_csv(os.path.join(input_dir,"user_first.csv"),lineterminator="\n")
first_data = first_data.loc[first_data.userID.isin(regular_users)]  # reg users
first_data["weed_first"] = pd.to_datetime(first_data["weed_first"])
first_data["juul_first"] = pd.to_datetime(first_data["juul_first"])

# %%
## removing the rewteet text column completely
ids_ = juul_data.loc[juul_data['retweetText'].notnull()]["tweetId"]
juul_data.loc[juul_data.tweetId.isin(ids_),"tweetText"] = juul_data.loc[juul_data.tweetId.isin(ids_)]["retweetText"]
juul_data = juul_data.drop(["hashtags","retweetText"],axis=1)
len(juul_data) ## 1353987 (sanity check)
# Out:
# 1353987

# %%
len(juul_data) ## 1353987
len(juul_data.userID.unique()) ## 673724  reg users
# Out:
# 673724

# %%
pd.isnull(list(first_data.loc[first_data.userID == 2534]["weed_first"])[0])
# Out:
# True

# %%
## get the users who start at jan 2018 
users_2018 = list(first_data["userID"][ 
    (first_data.juul_first.dt.year == 2018)
    & ((first_data.weed_first.dt.year == 2018) | (pd.isnull(first_data.weed_first)))
    & (first_data.juul_first.dt.month== 1)   ## selecting 2018, Jan data
    & (((first_data.weed_first.dt.date) > (first_data.juul_first.dt.date)) | (pd.isnull(first_data.weed_first)))
    & ((first_data.weed_first.dt.month >= 9) | (pd.isnull(first_data.weed_first)))]) # users who will change after september

poly_lbl = list(first_data["userID"].loc[(first_data.juul_first.dt.year == 2018)  
                                        & (first_data.juul_first.dt.month== 1) 
                                        & ((first_data.weed_first.dt.date) > (first_data.juul_first.dt.date))
                                        & ((first_data.weed_first.dt.month >= 9))
                                        & ((first_data.weed_first.dt.year == 2018))
                                        ])
                                            ## users that will change
print("total users", len(users_2018))
print("users will change",len(poly_lbl))
# Out:
# total users 10760
# users will change 929

# %%
data_2018 = juul_data.loc[juul_data.userID.isin(users_2018) & (juul_data.tweetCreatedAt.dt.year == 2018)]
print("total data", len(data_2018))
print("users",len(data_2018.userID.unique()))

## sanity check -- all users start in 2018 year..
data_2018 = juul_data.loc[juul_data.userID.isin(users_2018)]
print("total data", len(data_2018))
print("users",len(data_2018.userID.unique()))
# Out:
# total data 24018
# users 10760
# total data 24018
# users 10760

# %%
## get label - they reamain same for this task as the no of users, we only change the tweets data
users_ = data_2018.userID.unique()
users_labelled = pd.DataFrame(users_,columns=["userID"])
users_labelled["label"] = 0  ## initialize
users_labelled.loc[users_labelled.userID.isin(poly_lbl) , "label"] = 1
len(users_labelled.loc[users_labelled.label == 1])  ## sanity check
# Out:
# 929

# %%
bucket_data = []

# %%
bucket_data.append(preprocessing.get_month_data(data_2018,1,2))
bucket_data.append(preprocessing.get_month_data(data_2018,1,4))
bucket_data.append(preprocessing.get_month_data(data_2018,1,6))
bucket_data.append(preprocessing.get_month_data(data_2018,1,8))
# Out:
# length of the data 13087
# total users 10760
# length of the data 15477
# total users 10760
# length of the data 18204
# total users 10760
# length of the data 20383
# total users 10760

# %% [markdown]
# ## user are not changing in the month interval so need to get the text features scores..

# %% [markdown]
# ## text features

# %%
# oversampling
dimension = 100
epoch = 20
svm_scores = []
rf_scores = []
xgb_scores = []
lstm_scores = []
Y_tests = []
for data in bucket_data:
    train_data,test_data,Y_train, Y_test = preprocessing.prepare_data(data,users_labelled)
    
    ## lstm model
#     lstm_score, lstm_pred, lstm_model, keras_tkzr, max_len= driver.run_lstm(
#                                         train_data["tweetText"],test_data["tweetText"],Y_train, Y_test,
#                                         dimension,epoch,cross_splits=5,option="over",cross_val=True)
    
    # baseline models
    baseline_models, tfidf, svd =  driver.run_text_features(train_data["tweetText"], 
                                            test_data["tweetText"], Y_train, Y_test,
                                                            option="over",svd=True,cross_val=True)
    
#     svm_scores.append(baseline_models['svm'][1])
#     rf_scores.append(baseline_models['rf'][1])
#     xgb_scores.append(baseline_models['xgb'][1])
#     lstm_scores.append(lstm_score)

    Y_tests.append(Y_test)
# Out:
#   0%|          | 0/10760 [00:00<?, ?it/s]
#  50%|████▉     | 5333/10760 [00:00<00:00, 53326.87it/s]
#  98%|█████████▊| 10493/10760 [00:00<00:00, 52796.27it/s]
# 100%|██████████| 10760/10760 [00:00<00:00, 50545.10it/s]
#   0%|          | 0/10760 [00:00<?, ?it/s]
#   2%|▏         | 245/10760 [00:00<00:04, 2448.89it/s]
#   4%|▍         | 435/10760 [00:00<00:04, 2250.27it/s]
#   6%|▌         | 665/10760 [00:00<00:04, 2260.41it/s]
#   8%|▊         | 881/10760 [00:00<00:04, 2228.56it/s]
#  10%|█         | 1081/10760 [00:00<00:04, 2153.24it/s]
#  12%|█▏        | 1314/10760 [00:00<00:04, 2202.92it/s]
#  14%|█▍        | 1532/10760 [00:00<00:04, 2195.96it/s]
#  16%|█▋        | 1755/10760 [00:00<00:04, 2205.72it/s]
#  19%|█▊        | 2006/10760 [00:00<00:03, 2288.73it/s]
#  21%|██        | 2227/10760 [00:01<00:03, 2231.81it/s]
#  23%|██▎       | 2456/10760 [00:01<00:03, 2248.69it/s]
#  25%|██▍       | 2677/10760 [00:01<00:03, 2213.28it/s]
#  27%|██▋       | 2905/10760 [00:01<00:03, 2231.59it/s]
#  29%|██▉       | 3127/10760 [00:01<00:03, 2192.85it/s]
#  31%|███       | 3346/10760 [00:01<00:03, 2122.64it/s]
#  33%|███▎      | 3580/10760 [00:01<00:03, 2183.09it/s]
#  35%|███▌      | 3799/10760 [00:01<00:03, 2103.12it/s]
#  37%|███▋      | 4011/10760 [00:01<00:03, 2098.02it/s]
#  39%|███▉      | 4222/10760 [00:01<00:03, 2093.65it/s]
#  41%|████▏     | 4450/10760 [00:02<00:02, 2143.52it/s]
#  43%|████▎     | 4665/10760 [00:02<00:02, 2126.50it/s]
#  45%|████▌     | 4879/10760 [00:02<00:02, 2011.57it/s]
#  47%|████▋     | 5088/10760 [00:02<00:02, 2034.08it/s]
#  49%|████▉     | 5319/10760 [00:02<00:02, 2109.52it/s]
#  51%|█████▏    | 5532/10760 [00:02<00:02, 2066.08it/s]
#  53%|█████▎    | 5755/10760 [00:02<00:02, 2109.75it/s]
#  55%|█████▌    | 5968/10760 [00:02<00:02, 2018.31it/s]
#  57%|█████▋    | 6172/10760 [00:02<00:02, 1972.13it/s]
#  59%|█████▉    | 6385/10760 [00:03<00:02, 2015.98it/s]
#  61%|██████    | 6583/10760 [00:04<00:02, 1486.55it/s]
#  63%|██████▎   | 6734/10760 [00:04<00:02, 1463.81it/s]
#  64%|██████▍   | 6894/10760 [00:04<00:02, 1498.15it/s]
#  65%|██████▌   | 7045/10760 [00:04<00:02, 1493.50it/s]
#  67%|██████▋   | 7196/10760 [00:04<00:02, 1457.99it/s]
#  68%|██████▊   | 7343/10760 [00:04<00:02, 1370.51it/s]
#  70%|██████▉   | 7504/10760 [00:05<00:02, 1425.44it/s]
#  71%|███████   | 7649/10760 [00:05<00:02, 1410.36it/s]
#  72%|███████▏  | 7796/10760 [00:05<00:02, 1426.87it/s]
#  74%|███████▍  | 7940/10760 [00:05<00:02, 1393.68it/s]
#  75%|███████▌  | 8086/10760 [00:05<00:01, 1401.12it/s]
#  76%|███████▋  | 8227/10760 [00:05<00:01, 1397.13it/s]
#  78%|███████▊  | 8370/10760 [00:05<00:01, 1404.01it/s]
#  79%|███████▉  | 8537/10760 [00:05<00:01, 1470.53it/s]
#  81%|████████  | 8686/10760 [00:05<00:01, 1435.51it/s]
#  82%|████████▏ | 8831/10760 [00:05<00:01, 1400.94it/s]
#  83%|████████▎ | 8972/10760 [00:06<00:01, 1391.83it/s]
#  85%|████████▍ | 9112/10760 [00:06<00:01, 1359.43it/s]
#  86%|████████▌ | 9260/10760 [00:06<00:01, 1390.49it/s]
#  87%|████████▋ | 9400/10760 [00:06<00:01, 1350.68it/s]
#  89%|████████▉ | 9557/10760 [00:06<00:00, 1384.50it/s]
#  90%|█████████ | 9734/10760 [00:06<00:00, 1481.10it/s]
#  92%|█████████▏| 9927/10760 [00:06<00:00, 1591.54it/s]
#  94%|█████████▍| 10104/10760 [00:06<00:00, 1637.02it/s]
#  96%|█████████▌| 10284/10760 [00:06<00:00, 1670.30it/s]
#  97%|█████████▋| 10454/10760 [00:07<00:00, 1613.84it/s]
#  99%|█████████▊| 10623/10760 [00:07<00:00, 1626.55it/s]
# 100%|██████████| 10760/10760 [00:07<00:00, 1489.93it/s]
# train-test split
# after sampling postives in train  7865 total lenggth: 15730
# training the models
# X_train shape (15730, 100)
# X_test shape (2152, 100)
# svm
# [LibLinear]random_forest
# xgBoost
# /home/xavlock2345/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# [LibLinear][LibLinear]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-45-d9d0f2e11112> in <module>
#      18     baseline_models, tfidf, svd =  driver.run_text_features(train_data["tweetText"],
#      19                                             test_data["tweetText"], Y_train, Y_test,
# ---> 20                                                             option="over",svd=True,cross_val=True)
#      21
#      22 #     svm_scores.append(baseline_models['svm'][1])
#
# ~/twitter_juul/src/preprocess/escalation/driver.py in run_text_features(train_data, test_data, Y_train, Y_test, option, svd, cross_val)
#      53                 X_test = X_test.toarray()    ## because of sparse array
#      54
# ---> 55         baseline_models = baselines.get_baseline_scores(X_train, X_test, Y_train, Y_test,cross_val=cross_val)
#      56         return (baseline_models, tf_idf, svd)
#      57
#
# ~/twitter_juul/src/preprocess/escalation/baselines.py in get_baseline_scores(X_train, X_test, Y_train, Y_test, cross_val)
#      60                 Y = np.array(list(Y_train) + list(Y_test))  ## for corss val
#      61                 X = np.concatenate((X_train, X_test), axis=0)  ## for cross_val
# ---> 62                 svm_f1 = util.get_cross_val(svm, X, Y, n_splits=5)
#      63                 rf_f1 = util.get_cross_val(rf, X, Y, n_splits=5)
#      64                 xgb_f1 = util.get_cross_val(xgb, X, Y, n_splits=5)
#
# ~/twitter_juul/src/preprocess/escalation/util.py in get_cross_val(model, X, Y, n_splits)
#     168         scores = []
#     169         for train, test in kFold.split(X, Y):
# --> 170                 model.fit(X[train], Y[train])
#     171                 y_pred = model.predict(X[test])
#     172                 scores.append(precision_recall_fscore_support(Y[test], y_pred, average=None)[2])
#
# ~/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/svm/classes.py in fit(self, X, y, sample_weight)
#     233             self.class_weight, self.penalty, self.dual, self.verbose,
#     234             self.max_iter, self.tol, self.random_state, self.multi_class,
# --> 235             self.loss, sample_weight=sample_weight)
#     236
#     237         if self.multi_class == "crammer_singer" and len(self.classes_) == 2:
#
# ~/anaconda3/envs/metis-env/lib/python3.6/site-packages/sklearn/svm/base.py in _fit_liblinear(X, y, C, fit_intercept, intercept_scaling, class_weight, penalty, dual, verbose, max_iter, tol, random_state, multi_class, loss, epsilon, sample_weight)
#     888         X, y_ind, sp.isspmatrix(X), solver_type, tol, bias, C,
#     889         class_weight_, max_iter, rnd.randint(np.iinfo('i').max),
# --> 890         epsilon, sample_weight)
#     891     # Regarding rnd.randint(..) in the above signature:
#     892     # seed for srand in range [0..INT_MAX); due to limitations in Numpy
#
# KeyboardInterrupt:

# %%
# dump_scores
scores_over = {"svm_scores" : svm_scores,
               "rf_scores" : rf_scores,
               "lstm" : lstm_scores,
               "xgb" : xgb_scores}

with open(os.path.join(model_dir,"text_over_month_scores.pkl"),"wb") as f:
    pickle.dump(scores_over,f)

# %% [markdown]
# ## plotting

# %%
scores = pickle.load(open(os.path.join(model_dir,"text_over_month_scores.pkl"),"rb"))

# %%
scores["lstm"]
# Out:
# [(0.8353255669336013, 0.7257933157285448),
#  (0.8605957500202066, 0.7894061533207751),
#  (0.8832808252925256, 0.8278279740054486),
#  (0.8937535734314093, 0.8469521195514453)]

# %%
for score in scores["lstm"]:
    print(np.mean(score))
# Out:
# 0.780559441331073
# 0.8250009516704908
# 0.8555543996489872
# 0.8703528464914273

# %%
#### @TODO look at the plots
scores_under = pickle.load(open(os.path.join(model_dir,"text_over_month_scores.pkl"),"rb"))
svm_scores =  scores_under["svm_scores"]
rf_scores = scores_under["rf_scores"]
xgb_scores = scores_under["xgb"]
lstm_scores = scores_under["lstm"]

# %%
from sklearn.metrics import precision_recall_fscore_support
maj_scores_neg = []
maj_scores_pos = []
for Y_test in Y_tests:
    y_pred_neg = [0 for x in range(len(Y_test))]
    y_pred_pos = [1 for x in range(len(Y_test))]
    print("length of Y_test",len(Y_test))
    print("positives in Y_test", (util.get_postives(Y_test)))
    maj_pos = precision_recall_fscore_support(Y_test,y_pred_pos,average=None)[2][0]
    maj_scores_pos.append(maj_pos)
    maj_neg = precision_recall_fscore_support(Y_test,y_pred_neg,average=None)[2][0]
    maj_scores_neg.append(maj_neg)
# Out:
# length of Y_test 2152
# positives in Y_test 186
# length of Y_test 2152
# positives in Y_test 186
# length of Y_test 2152
# positives in Y_test 186
# length of Y_test 2152
# positives in Y_test 186

# %%
svm = [ele[0] for ele in svm_scores]
rf = [ele[0] for ele in rf_scores]
xgb = [ele[0] for ele in xgb_scores]
lstm = [ele[0] for ele in lstm_scores]
maj_score_pos = [ele for ele in maj_scores_pos]
maj_score_neg = [ele for ele in maj_scores_neg]
## plotting user features
plt.figure(figsize=(15,7))
months = ["1_Jan-Feb","2_Mar-Apr","3_May-Jun","4_Jul-Aug"]
plt.plot(months,maj_score_pos,label="majority all change to poly")
plt.plot(months,maj_score_neg,label="majority remain mono")
plt.plot(months,svm,label="svm")
plt.plot(months,rf,label="rf")
plt.plot(months,xgb,label="xg-boost")
plt.plot(months,lstm,label="lstm")
plt.title("Performance of classifiers for predicting mono users using user features by month interval")
plt.ylabel("F1 score")
plt.legend()
plt.show()

# %%
svm = [ele[1] for ele in svm_scores]
rf = [ele[1] for ele in rf_scores]
xgb = [ele[1] for ele in xgb_scores]
lstm = [ele[1] for ele in lstm_scores]
maj_score_pos = [ele for ele in maj_scores_pos]
maj_score_neg = [ele for ele in maj_scores_neg]
## plotting user features
plt.figure(figsize=(15,7))
months = ["1_Jan-Feb","2_Mar-Apr","3_May-Jun","4_Jul-Aug"]
plt.plot(months,maj_score_pos,label="majority all change to poly")
plt.plot(months,maj_score_neg,label="majority remain mono")
plt.plot(months,svm,label="svm")
plt.plot(months,rf,label="rf")
plt.plot(months,xgb,label="xg-boost")
plt.plot(months,lstm,label="lstm")
plt.title("Performance of classifiers for predicting poly users using user features by month interval")
plt.ylabel("F1 score")
plt.legend()
plt.show()

# %% [markdown]
# ## user features are not captured as users are not chnaging in the month interval

# %%
for svm,tf_idf,month in zip(svm_models,tfidf_list,months):
    print(month)
    plot_coeff(20,svm,tf_idf.get_feature_names())

# %%
## might need to use it
dr = (cleaned_data_list)[3]
dr.loc[dr["tweetText"].apply(get_length) > 70]
# Out:
#                   userID  \
# 2     22363298
# 9     36601913
# 10    40020666
# 32    84390643
# 42    107734376
# 43    111784704
# 47    131865756
# 48    136512116
# 55    153162730
# 66    182011274
# 67    201555589
# 74    232472970
# 80    247814229
# 81    250961859
# 85    256834162
# 87    258632824
# 94    276138972
# 95    277745271
# 96    282296776
# 101   298773620
# 102   298885267
# 106   309223772
# 107   316815353
# 110   322160143
# 112   324429841
# 118   331309834
# 119   331435329
# 121   334972912
# 125   337452000
# 128   341168731
# ...         ...
# 1675  858469879623462913
# 1679  861455839630172161
# 1680  862047059368714240
# 1681  862497103687405570
# 1685  864166911638216705
# 1691  871389553902440448
# 1694  875873538330296321
# 1701  879212335642157057
# 1703  881906951449432065
# 1709  885690743355985921
# 1728  897593218325508100
# 1733  900399733721772032
# 1734  902978758080028672
# 1736  904803614031572992
# 1750  913307609913974784
# 1754  914626116379439105
# 1755  915328913471139842
# 1758  917160867283660800
# 1760  918509131165609984
# 1763  919746197774131206
# 1767  922880793239793665
# 1783  932739617228500997
# 1788  934893262892097536
# 1805  941357348442034176
# 1829  948387880149200901
# 1832  949868082591301632
# 1835  950900000673882113
# 1841  951951273473069056
# 1845  953349683392348161
# 1846  953438435712253952
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                
# 1835  Please bro lemme hit your juul bro please bro just one hit bro cmon bro lemme take a fat rip off your juul bro please bro I need your juul bro please lemme hit that juul bro please just one hit bro please bro I gottta have my juul fix bro please just one hit please bro juul me;you know who’s not gonna wake up and decide they don’t want me anymore? my juul. and that my friends, is true love.;“Wait I lost my juul”-everyone that owns a juul every 5 minutes before finding it again;when i die i will reincarnate as a juul pod;📂 My Pockets   └📁Wheres my juul       └📁 Fuck seriously where is my juul           └📁 Guys did u steal my juul               └📁 Oh its right here                  └😎 Fat rip;“She don’t wanna fuck she just wanna hit my juul”
# 1841  Please bro lemme hit your juul bro please bro just one hit bro cmon bro lemme take a fat rip off your juul bro please bro I need your juul bro please lemme hit that juul bro please just one hit bro please bro I gottta have my juul fix bro please just one hit please bro juul me;Nah the dumbest thing you can do is juul when you weren't even addicted to nicotine in the first place
# 1845   as long as you pass me the juul;This is mainly directed at those who never had a nic addiction before and then only bought a juul because they were “cool and everyone had one”   Weirdos;imagine having a nicotine addiction from a juul u bought just to fit in;Give me the:  🔘 AUX  🔘 Charger  🔘JUUL  ☑️ BEAT BOYS AND FREE MY SOUL, I WANNA GET LOST IN YOUR ROCK AND ROLL AND DRIFT AWAY;The fact that United States almost...ALMOST beat underage smoking/nicotine addiction and then y’all dumbasses started “JUUL-ing” is so fucking frustrating. Besides a single juul pod has more nicotine than an entire pack of cigarettes so don’t even gimme that “it’s better” bs.
# 1846  HE IS HITTING A FUCKING JUUL HAHA ;I can’t believe people are mad about the video of Jack hitting a juul? Literally every teenager does that? I think it’s really funny. “Jack stop my mom could come in any minute” and also people are like “another reason to hate jack” YOU THINK FINN DIDN’T HIT IT? HAHAHA;it’s not even that the fandom thinks jack vaping is bad (juul’s have nicotine so it is but that’s not the point) we think it’s funny as shit cause he took the weakest hit and tried to look cool as shit IM LAUGHING JUST THINKING ABOUT IT
#
#       label
# 2     1
# 9     1
# 10    0
# 32    1
# 42    0
# 43    1
# 47    1
# 48    0
# 55    1
# 66    1
# 67    0
# 74    0
# 80    0
# 81    0
# 85    1
# 87    1
# 94    0
# 95    1
# 96    1
# 101   1
# 102   0
# 106   1
# 107   0
# 110   1
# 112   0
# 118   1
# 119   1
# 121   1
# 125   0
# 128   0
# ...  ..
# 1675  1
# 1679  1
# 1680  1
# 1681  0
# 1685  1
# 1691  1
# 1694  1
# 1701  1
# 1703  1
# 1709  1
# 1728  1
# 1733  1
# 1734  1
# 1736  0
# 1750  1
# 1754  1
# 1755  0
# 1758  1
# 1760  0
# 1763  1
# 1767  0
# 1783  1
# 1788  1
# 1805  0
# 1829  0
# 1832  1
# 1835  0
# 1841  0
# 1845  1
# 1846  0
#
# [404 rows x 3 columns]

# %% [markdown]
# ## End

# %%
## without sequencing lstm
embedding_file = os.path.join(embeddings_dir,"glove.twitter.27B.100d.txt")
lstm_scores = []
lstm_models = []
cleaned_data_list = []
for data in bucket_data:
    print("********************")
    print("length of users",len(users_labelled))
    df,X,y,embedding_matrix,max_len,vocalb_size  = prepare_data_lstm(data,users_labelled)
    model,score = run_lstm_model(X,y,embedding_matrix,max_len,vocalb_size,dimension=100,epoch= 6,metrics=metrics)
    lstm_scores.append(score)
    lstm_models.append(model)
    cleaned_data_list.append(df)
# Out:
# ********************
# length of users 10760
# length of the data 13087
# users 10760
# cleanining the data
# HBox(children=(IntProgress(value=0, max=13087), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=13087), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=13087), HTML(value='')))
# max_length 45
# total users before 10760
# length of positive samples before 929
# length of positive samples after 929
# total users after 1858
# before data 13087
# users before 10760
# after data 2410
# after users 1858
# preparing the tokenizer
# vocalb 2825
# creating glove embeddign matrix
# encoding the data
# X (1858, 45)
# y (1858,)
# train-test split
# X-train (1114, 45)
# X-test (372, 45)
# creating lstm model
# creating model
# compiling the model
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         (None, 45)                0
# _________________________________________________________________
# embedding_7 (Embedding)      (None, 45, 100)           282500
# _________________________________________________________________
# bidirectional_7 (Bidirection (None, 45, 200)           160800
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 9000)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 100)               900100
# _________________________________________________________________
# dense_8 (Dense)              (None, 2)                 202
# =================================================================
# Total params: 1,343,602
# Trainable params: 1,343,602
# Non-trainable params: 0
# _________________________________________________________________
# training the model with balance dataset
# Train on 1114 samples, validate on 372 samples
# Epoch 1/6
# 1114/1114 [==============================] - 13s 12ms/step - loss: 0.7090 - acc: 0.5413 - val_loss: 0.6956 - val_acc: 0.4973
# — val_f1: 0.000000 — val_precision: 0.000000 — val_recall 0.000000
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67       186
#            1       0.00      0.00      0.00       186
#
#     accuracy                           0.50       372
#    macro avg       0.25      0.50      0.33       372
# weighted avg       0.25      0.50      0.33       372
#
#
# Epoch 2/6
# 1114/1114 [==============================] - 8s 7ms/step - loss: 0.6854 - acc: 0.5628 - val_loss: 0.7076 - val_acc: 0.5242
# — val_f1: 0.000000 — val_precision: 0.000000 — val_recall 0.000000
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67       186
#            1       0.00      0.00      0.00       186
#
#     accuracy                           0.50       372
#    macro avg       0.25      0.50      0.33       372
# weighted avg       0.25      0.50      0.33       372
#
#
# Epoch 3/6
# 1114/1114 [==============================] - 8s 7ms/step - loss: 0.6762 - acc: 0.5754 - val_loss: 0.7059 - val_acc: 0.5054
# — val_f1: 0.041667 — val_precision: 0.666667 — val_recall 0.021505
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.50      0.99      0.67       186
#            1       0.67      0.02      0.04       186
#
#     accuracy                           0.51       372
#    macro avg       0.58      0.51      0.35       372
# weighted avg       0.58      0.51      0.35       372
#
#
# Epoch 4/6
# 1114/1114 [==============================] - 8s 7ms/step - loss: 0.6619 - acc: 0.5934 - val_loss: 0.7260 - val_acc: 0.5242
# — val_f1: 0.344569 — val_precision: 0.567901 — val_recall 0.247312
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.52      0.81      0.63       186
#            1       0.57      0.25      0.34       186
#
#     accuracy                           0.53       372
#    macro avg       0.54      0.53      0.49       372
# weighted avg       0.54      0.53      0.49       372
#
#
# Epoch 5/6
# 1114/1114 [==============================] - 8s 7ms/step - loss: 0.6432 - acc: 0.6346 - val_loss: 0.7442 - val_acc: 0.5108
# — val_f1: 0.273092 — val_precision: 0.539683 — val_recall 0.182796
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.51      0.84      0.63       186
#            1       0.54      0.18      0.27       186
#
#     accuracy                           0.51       372
#    macro avg       0.52      0.51      0.45       372
# weighted avg       0.52      0.51      0.45       372
#
#
# Epoch 6/6
# 1114/1114 [==============================] - 8s 7ms/step - loss: 0.6223 - acc: 0.6382 - val_loss: 0.7557 - val_acc: 0.4973
# — val_f1: 0.336770 — val_precision: 0.466667 — val_recall 0.263441
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.49      0.70      0.57       186
#            1       0.47      0.26      0.34       186
#
#     accuracy                           0.48       372
#    macro avg       0.48      0.48      0.46       372
# weighted avg       0.48      0.48      0.46       372
# generating classfication report
# Accuracy: 59.408602
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.61      0.52      0.56       186
#            1       0.58      0.67      0.62       186
#
#     accuracy                           0.59       372
#    macro avg       0.60      0.59      0.59       372
# weighted avg       0.60      0.59      0.59       372
#
#
# job finished
# ********************
# length of users 10760
# length of the data 15477
# users 10760
# cleanining the data
# HBox(children=(IntProgress(value=0, max=15477), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=15477), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=15477), HTML(value='')))
# max_length 45
# total users before 10760
# length of positive samples before 929
# length of positive samples after 929
# total users after 1858
# before data 15477
# users before 10760
# after data 3021
# after users 1858
# preparing the tokenizer
# vocalb 3254
# creating glove embeddign matrix
# encoding the data
# X (1858, 45)
# y (1858,)
# train-test split
# X-train (1114, 45)
# X-test (372, 45)
# creating lstm model
# creating model
# compiling the model
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         (None, 45)                0
# _________________________________________________________________
# embedding_8 (Embedding)      (None, 45, 100)           325400
# _________________________________________________________________
# bidirectional_8 (Bidirection (None, 45, 200)           160800
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 9000)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 100)               900100
# _________________________________________________________________
# dense_10 (Dense)             (None, 2)                 202
# =================================================================
# Total params: 1,386,502
# Trainable params: 1,386,502
# Non-trainable params: 0
# _________________________________________________________________
# training the model with balance dataset
# Train on 1114 samples, validate on 372 samples
# Epoch 1/6
# 1114/1114 [==============================] - 14s 12ms/step - loss: 0.7042 - acc: 0.5027 - val_loss: 0.6927 - val_acc: 0.5376
# — val_f1: 0.000000 — val_precision: 0.000000 — val_recall 0.000000
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67       186
#            1       0.00      0.00      0.00       186
#
#     accuracy                           0.50       372
#    macro avg       0.25      0.50      0.33       372
# weighted avg       0.25      0.50      0.33       372
#
#
# Epoch 2/6
# 1114/1114 [==============================] - 8s 7ms/step - loss: 0.6877 - acc: 0.5485 - val_loss: 0.6928 - val_acc: 0.5430
# — val_f1: 0.000000 — val_precision: 0.000000 — val_recall 0.000000
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67       186
#            1       0.00      0.00      0.00       186
#
#     accuracy                           0.50       372
#    macro avg       0.25      0.50      0.33       372
# weighted avg       0.25      0.50      0.33       372
#
#
# Epoch 3/6
# 1114/1114 [==============================] - 8s 7ms/step - loss: 0.6774 - acc: 0.5727 - val_loss: 0.7458 - val_acc: 0.5591
# — val_f1: 0.000000 — val_precision: 0.000000 — val_recall 0.000000
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67       186
#            1       0.00      0.00      0.00       186
#
#     accuracy                           0.50       372
#    macro avg       0.25      0.50      0.33       372
# weighted avg       0.25      0.50      0.33       372
#
#
# Epoch 4/6
# 1114/1114 [==============================] - 8s 7ms/step - loss: 0.6765 - acc: 0.5889 - val_loss: 0.6973 - val_acc: 0.5565
# — val_f1: 0.031746 — val_precision: 1.000000 — val_recall 0.016129
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67       186
#            1       1.00      0.02      0.03       186
#
#     accuracy                           0.51       372
#    macro avg       0.75      0.51      0.35       372
# weighted avg       0.75      0.51      0.35       372
#
#
# Epoch 5/6
# 1114/1114 [==============================] - 8s 7ms/step - loss: 0.6515 - acc: 0.6041 - val_loss: 0.7099 - val_acc: 0.5430
# — val_f1: 0.263830 — val_precision: 0.632653 — val_recall 0.166667
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.52      0.90      0.66       186
#            1       0.63      0.17      0.26       186
#
#     accuracy                           0.53       372
#    macro avg       0.58      0.53      0.46       372
# weighted avg       0.58      0.53      0.46       372
#
#
# Epoch 6/6
# 1114/1114 [==============================] - 8s 7ms/step - loss: 0.6202 - acc: 0.6445 - val_loss: 0.7267 - val_acc: 0.5296
# — val_f1: 0.136364 — val_precision: 0.441176 — val_recall 0.080645
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.49      0.90      0.64       186
#            1       0.44      0.08      0.14       186
#
#     accuracy                           0.49       372
#    macro avg       0.47      0.49      0.39       372
# weighted avg       0.47      0.49      0.39       372
# generating classfication report
# Accuracy: 56.720430
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.58      0.48      0.53       186
#            1       0.56      0.65      0.60       186
#
#     accuracy                           0.57       372
#    macro avg       0.57      0.57      0.56       372
# weighted avg       0.57      0.57      0.56       372
#
#
# job finished
# ********************
# length of users 10760
# length of the data 18204
# users 10760
# cleanining the data
# HBox(children=(IntProgress(value=0, max=18204), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=18204), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=18204), HTML(value='')))
# max_length 45
# total users before 10760
# length of positive samples before 929
# length of positive samples after 929
# total users after 1858
# before data 18204
# users before 10760
# after data 3767
# after users 1858
# preparing the tokenizer
# vocalb 3753
# creating glove embeddign matrix
# encoding the data
# X (1858, 45)
# y (1858,)
# train-test split
# X-train (1114, 45)
# X-test (372, 45)
# creating lstm model
# creating model
# compiling the model
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         (None, 45)                0
# _________________________________________________________________
# embedding_9 (Embedding)      (None, 45, 100)           375300
# _________________________________________________________________
# bidirectional_9 (Bidirection (None, 45, 200)           160800
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 9000)              0
# _________________________________________________________________
# dense_11 (Dense)             (None, 100)               900100
# _________________________________________________________________
# dense_12 (Dense)             (None, 2)                 202
# =================================================================
# Total params: 1,436,402
# Trainable params: 1,436,402
# Non-trainable params: 0
# _________________________________________________________________
# training the model with balance dataset
# Train on 1114 samples, validate on 372 samples
# Epoch 1/6
# 1114/1114 [==============================] - 14s 12ms/step - loss: 0.6904 - acc: 0.5404 - val_loss: 0.6896 - val_acc: 0.5645
# — val_f1: 0.000000 — val_precision: 0.000000 — val_recall 0.000000
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67       186
#            1       0.00      0.00      0.00       186
#
#     accuracy                           0.50       372
#    macro avg       0.25      0.50      0.33       372
# weighted avg       0.25      0.50      0.33       372
#
#
# Epoch 2/6
# 1114/1114 [==============================] - 9s 8ms/step - loss: 0.6766 - acc: 0.5566 - val_loss: 0.6887 - val_acc: 0.5484
# — val_f1: 0.000000 — val_precision: 0.000000 — val_recall 0.000000
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67       186
#            1       0.00      0.00      0.00       186
#
#     accuracy                           0.50       372
#    macro avg       0.25      0.50      0.33       372
# weighted avg       0.25      0.50      0.33       372
#
#
# Epoch 3/6
# 1114/1114 [==============================] - 8s 8ms/step - loss: 0.6757 - acc: 0.5610 - val_loss: 0.6916 - val_acc: 0.5860
# — val_f1: 0.000000 — val_precision: 0.000000 — val_recall 0.000000
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67       186
#            1       0.00      0.00      0.00       186
#
#     accuracy                           0.50       372
#    macro avg       0.25      0.50      0.33       372
# weighted avg       0.25      0.50      0.33       372
#
#
# Epoch 4/6
# 1114/1114 [==============================] - 9s 8ms/step - loss: 0.6710 - acc: 0.5835 - val_loss: 0.6892 - val_acc: 0.5672
# — val_f1: 0.020833 — val_precision: 0.333333 — val_recall 0.010753
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.50      0.98      0.66       186
#            1       0.33      0.01      0.02       186
#
#     accuracy                           0.49       372
#    macro avg       0.42      0.49      0.34       372
# weighted avg       0.42      0.49      0.34       372
#
#
# Epoch 5/6
# 1114/1114 [==============================] - 8s 7ms/step - loss: 0.6440 - acc: 0.6275 - val_loss: 0.6957 - val_acc: 0.5941
# — val_f1: 0.089109 — val_precision: 0.562500 — val_recall 0.048387
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.50      0.96      0.66       186
#            1       0.56      0.05      0.09       186
#
#     accuracy                           0.51       372
#    macro avg       0.53      0.51      0.37       372
# weighted avg       0.53      0.51      0.37       372
#
#
# Epoch 6/6
# 1114/1114 [==============================] - 8s 7ms/step - loss: 0.5955 - acc: 0.6589 - val_loss: 0.7221 - val_acc: 0.5349
# — val_f1: 0.218341 — val_precision: 0.581395 — val_recall 0.134409
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.51      0.90      0.65       186
#            1       0.58      0.13      0.22       186
#
#     accuracy                           0.52       372
#    macro avg       0.55      0.52      0.44       372
# weighted avg       0.55      0.52      0.44       372
# generating classfication report
# Accuracy: 61.021505
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.62      0.56      0.59       186
#            1       0.60      0.66      0.63       186
#
#     accuracy                           0.61       372
#    macro avg       0.61      0.61      0.61       372
# weighted avg       0.61      0.61      0.61       372
#
#
# job finished
# ********************
# length of users 10760
# length of the data 20383
# users 10760
# cleanining the data
# HBox(children=(IntProgress(value=0, max=20383), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20383), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20383), HTML(value='')))
# max_length 45
# total users before 10760
# length of positive samples before 929
# length of positive samples after 929
# total users after 1858
# before data 20383
# users before 10760
# after data 4389
# after users 1858
# preparing the tokenizer
# vocalb 4151
# creating glove embeddign matrix
# encoding the data
# X (1858, 45)
# y (1858,)
# train-test split
# X-train (1114, 45)
# X-test (372, 45)
# creating lstm model
# creating model
# compiling the model
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        (None, 45)                0
# _________________________________________________________________
# embedding_10 (Embedding)     (None, 45, 100)           415100
# _________________________________________________________________
# bidirectional_10 (Bidirectio (None, 45, 200)           160800
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 9000)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 100)               900100
# _________________________________________________________________
# dense_14 (Dense)             (None, 2)                 202
# =================================================================
# Total params: 1,476,202
# Trainable params: 1,476,202
# Non-trainable params: 0
# _________________________________________________________________
# training the model with balance dataset
# Train on 1114 samples, validate on 372 samples
# Epoch 1/6
# 1114/1114 [==============================] - 14s 13ms/step - loss: 0.6893 - acc: 0.5709 - val_loss: 0.6889 - val_acc: 0.5887
# — val_f1: 0.000000 — val_precision: 0.000000 — val_recall 0.000000
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67       186
#            1       0.00      0.00      0.00       186
#
#     accuracy                           0.50       372
#    macro avg       0.25      0.50      0.33       372
# weighted avg       0.25      0.50      0.33       372
#
#
# Epoch 2/6
# 1114/1114 [==============================] - 9s 8ms/step - loss: 0.6690 - acc: 0.5799 - val_loss: 0.6892 - val_acc: 0.5968
# — val_f1: 0.050000 — val_precision: 0.357143 — val_recall 0.026882
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.49      0.95      0.65       186
#            1       0.36      0.03      0.05       186
#
#     accuracy                           0.49       372
#    macro avg       0.43      0.49      0.35       372
# weighted avg       0.43      0.49      0.35       372
#
#
# Epoch 3/6
# 1114/1114 [==============================] - 8s 8ms/step - loss: 0.6499 - acc: 0.6086 - val_loss: 0.6934 - val_acc: 0.5995
# — val_f1: 0.060606 — val_precision: 0.500000 — val_recall 0.032258
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.50      0.97      0.66       186
#            1       0.50      0.03      0.06       186
#
#     accuracy                           0.50       372
#    macro avg       0.50      0.50      0.36       372
# weighted avg       0.50      0.50      0.36       372
#
#
# Epoch 4/6
# 1114/1114 [==============================] - 8s 8ms/step - loss: 0.5993 - acc: 0.6427 - val_loss: 0.7399 - val_acc: 0.5887
# — val_f1: 0.231111 — val_precision: 0.666667 — val_recall 0.139785
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.52      0.93      0.67       186
#            1       0.67      0.14      0.23       186
#
#     accuracy                           0.53       372
#    macro avg       0.59      0.53      0.45       372
# weighted avg       0.59      0.53      0.45       372
#
#
# Epoch 5/6
# 1114/1114 [==============================] - 9s 8ms/step - loss: 0.5830 - acc: 0.6715 - val_loss: 0.7708 - val_acc: 0.5914
# — val_f1: 0.275000 — val_precision: 0.611111 — val_recall 0.177419
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.52      0.89      0.65       186
#            1       0.61      0.18      0.27       186
#
#     accuracy                           0.53       372
#    macro avg       0.56      0.53      0.46       372
# weighted avg       0.56      0.53      0.46       372
#
#
# Epoch 6/6
# 1114/1114 [==============================] - 9s 8ms/step - loss: 0.5413 - acc: 0.7038 - val_loss: 0.8649 - val_acc: 0.5618
# — val_f1: 0.514451 — val_precision: 0.556250 — val_recall 0.478495
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.54      0.62      0.58       186
#            1       0.56      0.48      0.51       186
#
#     accuracy                           0.55       372
#    macro avg       0.55      0.55      0.55       372
# weighted avg       0.55      0.55      0.55       372
# generating classfication report
# Accuracy: 58.870968
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.64      0.41      0.50       186
#            1       0.57      0.77      0.65       186
#
#     accuracy                           0.59       372
#    macro avg       0.60      0.59      0.57       372
# weighted avg       0.60      0.59      0.57       372
#
#
# job finished

# %%
## dump the scores
# with open(os.path.join(input_dir,"sequence_score.pkl"),"wb") as f:
#     pickle.dump(sequence_scores,f)

# with open(os.path.join(input_dir,"sequence_models.pkl"),"wb") as f:
#     pickle.dump(sequence_models,f)
    
# with open(os.path.join(input_dir,"svm_models.pkl"),"wb") as f:
#     pickle.dump(svm_models,f)

# with open(os.path.join(input_dir,"tf_idfs.pkl"),"wb") as f:
#     pickle.dump(tfidf_list,f)

# %%
sequence_scores = pickle.load(open(os.path.join(input_dir,"sequence_score.pkl"),"rb"))

# %% [markdown]
# ## Sequence models

# %%
svm = [ele[0] for ele in svm_scores]
rf = [ele[0] for ele in rf_scores]
xgb = [ele[0] for ele in xgb_scores]
y_pred_maj = [0 for x in range(len(Y_test))]
maj_score = precision_recall_fscore_support(Y_test,y_pred_maj,average=None)[2][0]
## plotting user features
plt.figure(figsize=(15,7))
years = ["2014-15","2015-16","2016-17"]
plt.plot(years,3*[maj_score],label="majority classifier")
plt.plot(years,svm,label="svm")
plt.plot(years,rf,label="rf")
plt.plot(years,xgb,label="xg-boost")
plt.title("Performance of classifiers for predicting mono users using User Features")
plt.ylabel("F1 score")
plt.legend()
plt.show()

# %%
svm = [ele[1] for ele in svm_scores]
rf = [ele[1] for ele in rf_scores]
xgb = [ele[1] for ele in xgb_scores]
## plotting user features
plt.figure(figsize=(15,7))
years = ["2014-15","2015-16","2016-17"]
plt.plot(years,3*[maj_score],label="majority classifier")
plt.plot(years,svm,label="svm")
plt.plot(years,rf,label="rf")
plt.plot(years,xgb,label="xg-boost")
plt.title("Performance of classifiers for predicting mono users using User Features")
plt.ylabel("F1 score")
plt.legend()
plt.show()

# %%
# will run lstm and other baseline models
embedding_file = os.path.join(embeddings_dir,"glove.twitter.27B.100d.txt")
sequence_scores = []
sequence_models = []
cleaned_data_list = []
for year,data,users_lbl in bucket_list:
    print("********************")
    print("year",year)
    print("length of users",len(users_lbl))
    df,X,y,embedding_matrix,window,max_len,vocalb_size  = prepare_data_rnn(data,users_lbl)
    model,score = run_sequence_model(X,y,embedding_matrix,window,max_len,vocalb_size,epoch= 6,metrics=metrics)
    sequence_scores.append(score)
    sequence_models.append(model)
    cleaned_data_list.append(df)
# Out:
# ********************
# year 2015
# length of users 1049
# length of the data 2944
# users 1049
# cleanining the data
# HBox(children=(IntProgress(value=0, max=2944), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=2944), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=2944), HTML(value='')))
# max_length 16
# window_size 8
# preparing the tokenizer
# vocalb 5653
# creating glove embeddign matrix
# encoding the data
# total users before 1049
# length of positive samples before 97
# length of positive samples after 97
# total users after 194
# before data 2944
# users before 1049
# after data 727
# after users 194
# getting the output label
# sequencing data
# HBox(children=(IntProgress(value=0, max=194), HTML(value='')))
# train-test split
# X-train (116, 8, 16)
# X-test (39, 8, 16)
# creating lstm model
# compiling the model
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_17 (InputLayer)        (None, 8, 16)             0
# _________________________________________________________________
# embedding_17 (Embedding)     (None, 8, 16, 100)        565300
# _________________________________________________________________
# reshape_10 (Reshape)         (None, 8, 1600)           0
# _________________________________________________________________
# bidirectional_17 (Bidirectio (None, 200)               1360800
# _________________________________________________________________
# dense_24 (Dense)             (None, 2)                 402
# =================================================================
# Total params: 1,926,502
# Trainable params: 1,926,502
# Non-trainable params: 0
# _________________________________________________________________
# None
# adjusting the weights for each class
# None
# training the model with balance dataset
# Train on 116 samples, validate on 39 samples
# Epoch 1/6
# 116/116 [==============================] - 8s 69ms/step - loss: 0.7026 - acc: 0.4741 - val_loss: 0.6854 - val_acc: 0.6667
# — val_f1: 0.307692 — val_precision: 0.666667 — val_recall 0.200000
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.52      0.89      0.65        19
#            1       0.67      0.20      0.31        20
#
#     accuracy                           0.54        39
#    macro avg       0.59      0.55      0.48        39
# weighted avg       0.59      0.54      0.48        39
#
#
# Epoch 2/6
# 116/116 [==============================] - 1s 6ms/step - loss: 0.6180 - acc: 0.8017 - val_loss: 0.6858 - val_acc: 0.5128
# — val_f1: 0.153846 — val_precision: 0.333333 — val_recall 0.100000
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.45      0.79      0.58        19
#            1       0.33      0.10      0.15        20
#
#     accuracy                           0.44        39
#    macro avg       0.39      0.44      0.37        39
# weighted avg       0.39      0.44      0.36        39
#
#
# Epoch 3/6
# 116/116 [==============================] - 1s 7ms/step - loss: 0.5520 - acc: 0.8017 - val_loss: 0.6885 - val_acc: 0.5897
# — val_f1: 0.250000 — val_precision: 0.750000 — val_recall 0.150000
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.51      0.95      0.67        19
#            1       0.75      0.15      0.25        20
#
#     accuracy                           0.54        39
#    macro avg       0.63      0.55      0.46        39
# weighted avg       0.64      0.54      0.45        39
#
#
# Epoch 4/6
# 116/116 [==============================] - 1s 7ms/step - loss: 0.4796 - acc: 0.8879 - val_loss: 0.6883 - val_acc: 0.5641
# — val_f1: 0.181818 — val_precision: 1.000000 — val_recall 0.100000
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.51      1.00      0.68        19
#            1       1.00      0.10      0.18        20
#
#     accuracy                           0.54        39
#    macro avg       0.76      0.55      0.43        39
# weighted avg       0.76      0.54      0.42        39
#
#
# Epoch 5/6
# 116/116 [==============================] - 1s 6ms/step - loss: 0.3967 - acc: 0.8966 - val_loss: 0.6724 - val_acc: 0.6410
# — val_f1: 0.095238 — val_precision: 1.000000 — val_recall 0.050000
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67        19
#            1       1.00      0.05      0.10        20
#
#     accuracy                           0.51        39
#    macro avg       0.75      0.53      0.38        39
# weighted avg       0.76      0.51      0.37        39
#
#
# Epoch 6/6
# 116/116 [==============================] - 1s 6ms/step - loss: 0.3281 - acc: 0.8793 - val_loss: 0.6570 - val_acc: 0.6667
# — val_f1: 0.000000 — val_precision: 0.000000 — val_recall 0.000000
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.49      1.00      0.66        19
#            1       0.00      0.00      0.00        20
#
#     accuracy                           0.49        39
#    macro avg       0.24      0.50      0.33        39
# weighted avg       0.24      0.49      0.32        39
# generating classfication report
# Accuracy: 53.846154
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.56      0.50      0.53        20
#            1       0.52      0.58      0.55        19
#
#     accuracy                           0.54        39
#    macro avg       0.54      0.54      0.54        39
# weighted avg       0.54      0.54      0.54        39
#
#
# job finished
# ********************
# year 2016
# length of users 1636
# length of the data 6475
# users 1636
# cleanining the data
# HBox(children=(IntProgress(value=0, max=6475), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=6475), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=6475), HTML(value='')))
# max_length 17
# window_size 10
# preparing the tokenizer
# vocalb 7226
# creating glove embeddign matrix
# encoding the data
# total users before 1636
# length of positive samples before 259
# length of positive samples after 259
# total users after 518
# before data 6475
# users before 1636
# after data 2386
# after users 518
# getting the output label
# sequencing data
# HBox(children=(IntProgress(value=0, max=518), HTML(value='')))
# train-test split
# X-train (310, 10, 17)
# X-test (104, 10, 17)
# creating lstm model
# compiling the model
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_18 (InputLayer)        (None, 10, 17)            0
# _________________________________________________________________
# embedding_18 (Embedding)     (None, 10, 17, 100)       722600
# _________________________________________________________________
# reshape_11 (Reshape)         (None, 10, 1700)          0
# _________________________________________________________________
# bidirectional_18 (Bidirectio (None, 200)               1440800
# _________________________________________________________________
# dense_25 (Dense)             (None, 2)                 402
# =================================================================
# Total params: 2,163,802
# Trainable params: 2,163,802
# Non-trainable params: 0
# _________________________________________________________________
# None
# adjusting the weights for each class
# None
# training the model with balance dataset
# Train on 310 samples, validate on 104 samples
# Epoch 1/6
# 310/310 [==============================] - 10s 31ms/step - loss: 0.7037 - acc: 0.4645 - val_loss: 0.6789 - val_acc: 0.5577
# — val_f1: 0.294118 — val_precision: 0.625000 — val_recall 0.192308
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.52      0.88      0.66        52
#            1       0.62      0.19      0.29        52
#
#     accuracy                           0.54       104
#    macro avg       0.57      0.54      0.48       104
# weighted avg       0.57      0.54      0.48       104
#
#
# Epoch 2/6
# 310/310 [==============================] - 2s 8ms/step - loss: 0.6172 - acc: 0.7581 - val_loss: 0.6806 - val_acc: 0.5865
# — val_f1: 0.413793 — val_precision: 0.514286 — val_recall 0.346154
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.51      0.67      0.58        52
#            1       0.51      0.35      0.41        52
#
#     accuracy                           0.51       104
#    macro avg       0.51      0.51      0.50       104
# weighted avg       0.51      0.51      0.50       104
#
#
# Epoch 3/6
# 310/310 [==============================] - 2s 7ms/step - loss: 0.4909 - acc: 0.8323 - val_loss: 0.7113 - val_acc: 0.5385
# — val_f1: 0.037736 — val_precision: 1.000000 — val_recall 0.019231
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67        52
#            1       1.00      0.02      0.04        52
#
#     accuracy                           0.51       104
#    macro avg       0.75      0.51      0.35       104
# weighted avg       0.75      0.51      0.35       104
#
#
# Epoch 4/6
# 310/310 [==============================] - 2s 7ms/step - loss: 0.3349 - acc: 0.8645 - val_loss: 0.8714 - val_acc: 0.5192
# — val_f1: 0.000000 — val_precision: 0.000000 — val_recall 0.000000
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67        52
#            1       0.00      0.00      0.00        52
#
#     accuracy                           0.50       104
#    macro avg       0.25      0.50      0.33       104
# weighted avg       0.25      0.50      0.33       104
#
#
# Epoch 5/6
# 310/310 [==============================] - 2s 7ms/step - loss: 0.2152 - acc: 0.9097 - val_loss: 1.1721 - val_acc: 0.5481
# — val_f1: 0.000000 — val_precision: 0.000000 — val_recall 0.000000
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.50      0.98      0.66        52
#            1       0.00      0.00      0.00        52
#
#     accuracy                           0.49       104
#    macro avg       0.25      0.49      0.33       104
# weighted avg       0.25      0.49      0.33       104
#
#
# Epoch 6/6
# 310/310 [==============================] - 2s 7ms/step - loss: 0.1688 - acc: 0.9194 - val_loss: 1.4299 - val_acc: 0.4712
# — val_f1: 0.103448 — val_precision: 0.500000 — val_recall 0.057692
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.50      0.94      0.65        52
#            1       0.50      0.06      0.10        52
#
#     accuracy                           0.50       104
#    macro avg       0.50      0.50      0.38       104
# weighted avg       0.50      0.50      0.38       104
# generating classfication report
# Accuracy: 52.884615
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.54      0.40      0.46        52
#            1       0.52      0.65      0.58        52
#
#     accuracy                           0.53       104
#    macro avg       0.53      0.53      0.52       104
# weighted avg       0.53      0.53      0.52       104
#
#
# job finished
# ********************
# year 2017
# length of users 40236
# length of the data 111735
# users 40236
# cleanining the data
# HBox(children=(IntProgress(value=0, max=111735), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=111735), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=111735), HTML(value='')))
# max_length 27
# window_size 9
# preparing the tokenizer
# vocalb 20598
# creating glove embeddign matrix
# encoding the data
# total users before 40236
# length of positive samples before 9306
# length of positive samples after 9306
# total users after 18612
# before data 111735
# users before 40236
# after data 62085
# after users 18612
# getting the output label
# sequencing data
# HBox(children=(IntProgress(value=0, max=18612), HTML(value='')))
# train-test split
# X-train (11166, 9, 27)
# X-test (3723, 9, 27)
# creating lstm model
# compiling the model
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_19 (InputLayer)        (None, 9, 27)             0
# _________________________________________________________________
# embedding_19 (Embedding)     (None, 9, 27, 100)        2059800
# _________________________________________________________________
# reshape_12 (Reshape)         (None, 9, 2700)           0
# _________________________________________________________________
# bidirectional_19 (Bidirectio (None, 200)               2240800
# _________________________________________________________________
# dense_26 (Dense)             (None, 2)                 402
# =================================================================
# Total params: 4,301,002
# Trainable params: 4,301,002
# Non-trainable params: 0
# _________________________________________________________________
# None
# adjusting the weights for each class
# None
# training the model with balance dataset
# Train on 11166 samples, validate on 3723 samples
# Epoch 1/6
# 11166/11166 [==============================] - 123s 11ms/step - loss: 0.6941 - acc: 0.5010 - val_loss: 0.6930 - val_acc: 0.5071
# — val_f1: 0.000000 — val_precision: 0.000000 — val_recall 0.000000
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67      1861
#            1       0.00      0.00      0.00      1862
#
#     accuracy                           0.50      3723
#    macro avg       0.25      0.50      0.33      3723
# weighted avg       0.25      0.50      0.33      3723
#
#
# Epoch 2/6
# 11166/11166 [==============================] - 115s 10ms/step - loss: 0.6912 - acc: 0.5257 - val_loss: 0.6947 - val_acc: 0.5154
# — val_f1: 0.001073 — val_precision: 0.500000 — val_recall 0.000537
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67      1861
#            1       0.50      0.00      0.00      1862
#
#     accuracy                           0.50      3723
#    macro avg       0.50      0.50      0.33      3723
# weighted avg       0.50      0.50      0.33      3723
#
#
# Epoch 3/6
# 11166/11166 [==============================] - 115s 10ms/step - loss: 0.6623 - acc: 0.5868 - val_loss: 0.7195 - val_acc: 0.5197
# — val_f1: 0.367182 — val_precision: 0.491007 — val_recall 0.293233
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.50      0.70      0.58      1861
#            1       0.49      0.29      0.37      1862
#
#     accuracy                           0.49      3723
#    macro avg       0.49      0.49      0.47      3723
# weighted avg       0.49      0.49      0.47      3723
#
#
# Epoch 4/6
# 11166/11166 [==============================] - 115s 10ms/step - loss: 0.5684 - acc: 0.6702 - val_loss: 0.7931 - val_acc: 0.5050
# — val_f1: 0.364206 — val_precision: 0.517822 — val_recall 0.280881
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.51      0.74      0.60      1861
#            1       0.52      0.28      0.36      1862
#
#     accuracy                           0.51      3723
#    macro avg       0.51      0.51      0.48      3723
# weighted avg       0.51      0.51      0.48      3723
#
#
# Epoch 5/6
# 11166/11166 [==============================] - 117s 10ms/step - loss: 0.4557 - acc: 0.7452 - val_loss: 0.9221 - val_acc: 0.5068
# — val_f1: 0.213478 — val_precision: 0.483871 — val_recall 0.136950
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.50      0.85      0.63      1861
#            1       0.48      0.14      0.21      1862
#
#     accuracy                           0.50      3723
#    macro avg       0.49      0.50      0.42      3723
# weighted avg       0.49      0.50      0.42      3723
#
#
# Epoch 6/6
# 11166/11166 [==============================] - 119s 11ms/step - loss: 0.3739 - acc: 0.7910 - val_loss: 1.0448 - val_acc: 0.5181
# — val_f1: 0.235392 — val_precision: 0.515426 — val_recall 0.152524
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.50      0.86      0.63      1861
#            1       0.52      0.15      0.24      1862
#
#     accuracy                           0.50      3723
#    macro avg       0.51      0.50      0.43      3723
# weighted avg       0.51      0.50      0.43      3723
# generating classfication report
# Accuracy: 50.282031
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.50      0.46      0.48      1862
#            1       0.50      0.55      0.52      1861
#
#     accuracy                           0.50      3723
#    macro avg       0.50      0.50      0.50      3723
# weighted avg       0.50      0.50      0.50      3723
#
#
# job finished

# %%
## without sequencing
embedding_file = os.path.join(embeddings_dir,"glove.twitter.27B.100d.txt")
lstm_scores = []
lstm_models = []
cleaned_data_list = []
for year,data,users_lbl in bucket_list:
    print("********************")
    print("year",year)
    print("length of users",len(users_lbl))
    df,X,y,embedding_matrix,max_len,vocalb_size  = prepare_data_lstm(data,users_lbl)
    model,score = run_lstm_model(X,y,embedding_matrix,max_len,vocalb_size,dimension=100,epoch= 6,metrics=metrics)
    lstm_scores.append(score)
    lstm_models.append(model)
    cleaned_data_list.append(df)
# Out:
# ********************
# year 2015
# length of users 1049
# length of the data 2944
# users 1049
# cleanining the data
# HBox(children=(IntProgress(value=0, max=2944), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=2944), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=2944), HTML(value='')))
# max_length 16
# total users before 1049
# length of positive samples before 97
# length of positive samples after 97
# total users after 194
# before data 2944
# users before 1049
# after data 727
# after users 194
# preparing the tokenizer
# vocalb 2393
# creating glove embeddign matrix

# %% [markdown]
# #### basline models

# %%
svm_scores = []
svm_models= []
rf_models= []
rf_scores = []
maj_scores = []
tfidf_list = []
xgb_scores = []
xgb_models = []
for year,data,users_lbl in bucket_list:
    print("********************")
    print("year",year)
    print("length of users",len(users_lbl))
    final = run_baslines(data,users_lbl,)
    svm_model,svm_score = final["svm"]
    rf_model, rf_score = final["rf"]
    xgb_model,xgb_score = final["xg_boost"]
    tf_idf = final["tf-idf"]
    maj_score = final["maj"]
    tfidf_list.append(tf_idf)
    svm_scores.append(svm_score)
    svm_models.append(svm_model)
    rf_scores.append(rf_score)
    rf_models.append(rf_model)
    xgb_scores.append(xgb_score)
    xgb_models.append(xgb_model)
    maj_scores.append(maj_score)

# %%
### plot for sequence scores
plt.figure(figsize=(15,7))
spans = ["2014-15","2015-16","2016-17"]
plt.plot(spans,lstm_scores,label="lstm")
plt.plot(spans,sequence_scores,label="sequence_lstm")
plt.plot(spans,(3*[maj_score]),label="majority classifier")
plt.plot(spans,svm_scores,label="svm")
plt.plot(spans,rf_scores,label="rf")
plt.plot(spans,xgb_scores,label="xg_boost")
plt.title("looking at performcnce of classfiers on different range year data(downsampled)")
plt.ylabel("weighted F1 score")
plt.legend()
plt.show()

# %%
### plot for sequence scores
plt.figure(figsize=(15,7))
spans = ["2014-15","2015-16","2016-17"]
plt.plot(spans,lstm_scores,label="lstm")
plt.plot(spans,sequence_scores,label="sequence_lstm")
plt.plot(spans,(3*[maj_score]),label="majority classifier")
plt.plot(spans,svm_scores,label="svm")
plt.plot(spans,rf_scores,label="rf")
plt.plot(spans,xgb_scores,label="xg_boost")
plt.title("looking at performcnce of classfiers on different range year data(downsampled)")
plt.ylabel("weighted F1 score")
plt.legend()
plt.show()

# %%
### plot for sequence scores
plt.figure(figsize=(15,7))
spans = ["2014-15","2015-16","2016-17"]
plt.plot(spans,lstm_scores,label="lstm")
plt.plot(spans,(3*[maj_score]),label="majority classifier")
plt.plot(spans,svm_scores,label="svm")
plt.plot(spans,rf_scores,label="rf")
plt.plot(spans,xgb_scores,label="xg_boost")
plt.title("looking at performcnce of classfiers on different range year data(downsampled)")
plt.ylabel("weighted F1 score")
plt.legend()
plt.show()

# %%
## most descriptive words by year
for svm,tf_idf,year in zip(svm_models,tfidf_list,spans):
    print(year)
    plot_coeff(20,svm,tf_idf.get_feature_names())

# %% [markdown]
# ### looking at cumulative range of data

# %%
bucket_list = []
## bucket 1
## 2014 -15 --
year = 2015
print("year",year)
users_ = list(first_data["userID"].loc[ 
    ((first_data.juul_first.dt.year <= year))
    & ((first_data.weed_first.dt.year == (year + 1)) | (pd.isnull(first_data.weed_first))) ## weed data after 2015
            ]) # users who will change after september

poly_turn = list(first_data["userID"].loc[(first_data.juul_first.dt.year <= year)  
                                        & ((first_data.weed_first.dt.year == (year +1 )))]) ## for labelling based on the next year


print("users that will change",len(poly_turn))
print("total users",len(users_))

## getting the input data
data_ = juul_data.loc[juul_data.userID.isin(users_)]
print("length of data",len(data_))

## get label - they reamain same for this task as the no of users, we only change the tweets data
users_ = data_.userID.unique()
users_lbl = pd.DataFrame(users_,columns=["userID"])
users_lbl["label"] = 0  ## initialize
users_lbl.loc[users_lbl.userID.isin(poly_turn) , "label"] = 1
len(users_lbl.loc[users_lbl.label == 1])  ## sanity check
bucket_list.append((year,data_,users_lbl))
# Out:
# year 2015
# users that will change 97
# total users 1049
# length of data 2944

# %%
## bucket 1
## 2014 -16 --
year = 2016
print("year",year)
users_ = list(first_data["userID"].loc[ 
    ((first_data.juul_first.dt.year <= year))
    & ((first_data.weed_first.dt.year == (year + 1)) | (pd.isnull(first_data.weed_first))) ## weed data after 2015
            ]) # users who will change after september

poly_turn = list(first_data["userID"].loc[(first_data.juul_first.dt.year <= year)  
                                        & ((first_data.weed_first.dt.year == (year +1 )))]) ## for labelling based on the next year


print("users that will change",len(poly_turn))
print("total users",len(users_))

## getting the input data
data_ = juul_data.loc[juul_data.userID.isin(users_)]
print("length of data",len(data_))

## get label - they reamain same for this task as the no of users, we only change the tweets data
users_ = data_.userID.unique()
users_lbl = pd.DataFrame(users_,columns=["userID"])
users_lbl["label"] = 0  ## initialize
users_lbl.loc[users_lbl.userID.isin(poly_turn) , "label"] = 1
len(users_lbl.loc[users_lbl.label == 1])  ## sanity check
bucket_list.append((year,data_,users_lbl))
# Out:
# year 2016
# users that will change 313
# total users 2642
# length of data 9456

# %%
## bucket 1
## 2014 -17 --
year = 2017
print("year",year)
users_ = list(first_data["userID"].loc[ 
    ((first_data.juul_first.dt.year <= year))
    & ((first_data.weed_first.dt.year == (year + 1)) | (pd.isnull(first_data.weed_first))) ## weed data after 2015
            ]) # users who will change after september

poly_turn = list(first_data["userID"].loc[(first_data.juul_first.dt.year <= year)  
                                        & ((first_data.weed_first.dt.year == (year +1 )))]) ## for labelling based on the next year


print("users that will change",len(poly_turn))
print("total users",len(users_))

## getting the input data
data_ = juul_data.loc[juul_data.userID.isin(users_)]
print("length of data",len(data_))

## get label - they reamain same for this task as the no of users, we only change the tweets data
users_ = data_.userID.unique()
users_lbl = pd.DataFrame(users_,columns=["userID"])
users_lbl["label"] = 0  ## initialize
users_lbl.loc[users_lbl.userID.isin(poly_turn) , "label"] = 1
len(users_lbl.loc[users_lbl.label == 1])  ## sanity check
bucket_list.append((year,data_,users_lbl))
# Out:
# year 2017
# users that will change 9525
# total users 42784
# length of data 120873

# %%
## RNN (LSTM)
embedding_file = os.path.join(embeddings_dir,"glove.twitter.27B.100d.txt")
lstm_scores = []
lstm_models = []
cleaned_data_list = []
for year,data,users_lbl in bucket_list:
    print("********************")
    print("year",year)
    print("length of users",len(users_lbl))
    df,X,y,embedding_matrix,max_len,vocalb_size  = prepare_data_lstm(data,users_lbl)
    model,score = run_lstm_model(X,y,embedding_matrix,max_len,vocalb_size,dimension=100,epoch= 6,metrics=metrics)
    lstm_scores.append(score)
    lstm_models.append(model)
    cleaned_data_list.append(df)
# Out:
# ********************
# year 2015
# length of users 1049
# length of the data 2944
# users 1049
# cleanining the data
# HBox(children=(IntProgress(value=0, max=2944), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=2944), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=2944), HTML(value='')))
# max_length 16
# total users before 1049
# length of positive samples before 97
# length of positive samples after 97
# total users after 194
# before data 2944
# users before 1049
# after data 727
# after users 194
# preparing the tokenizer
# vocalb 2393
# creating glove embeddign matrix
# encoding the data
# X (194, 16)
# y (194,)
# train-test split
# X-train (116, 16)
# X-test (39, 16)
# creating lstm model
# creating model
# compiling the model
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 16)                0
# _________________________________________________________________
# embedding_5 (Embedding)      (None, 16, 100)           239300
# _________________________________________________________________
# bidirectional_5 (Bidirection (None, 16, 200)           160800
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 3200)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 100)               320100
# _________________________________________________________________
# dense_10 (Dense)             (None, 2)                 202
# =================================================================
# Total params: 720,402
# Trainable params: 720,402
# Non-trainable params: 0
# _________________________________________________________________
# training the model with balance dataset
# Train on 116 samples, validate on 39 samples
# Epoch 1/6
# 116/116 [==============================] - 5s 44ms/step - loss: 0.6938 - acc: 0.5259 - val_loss: 0.6348 - val_acc: 0.6923
# — val_f1: 0.750000 — val_precision: 0.642857 — val_recall 0.900000
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.47      0.60        19
#            1       0.64      0.90      0.75        20
#
#     accuracy                           0.69        39
#    macro avg       0.73      0.69      0.68        39
# weighted avg       0.73      0.69      0.68        39
#
#
# Epoch 2/6
# 116/116 [==============================] - 0s 4ms/step - loss: 0.6801 - acc: 0.6121 - val_loss: 0.6642 - val_acc: 0.6154
# — val_f1: 0.181818 — val_precision: 1.000000 — val_recall 0.100000
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.51      1.00      0.68        19
#            1       1.00      0.10      0.18        20
#
#     accuracy                           0.54        39
#    macro avg       0.76      0.55      0.43        39
# weighted avg       0.76      0.54      0.42        39
#
#
# Epoch 3/6
# 116/116 [==============================] - 1s 4ms/step - loss: 0.6297 - acc: 0.7414 - val_loss: 0.6144 - val_acc: 0.7436
# — val_f1: 0.533333 — val_precision: 0.800000 — val_recall 0.400000
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.59      0.89      0.71        19
#            1       0.80      0.40      0.53        20
#
#     accuracy                           0.64        39
#    macro avg       0.69      0.65      0.62        39
# weighted avg       0.70      0.64      0.62        39
#
#
# Epoch 4/6
# 116/116 [==============================] - 1s 4ms/step - loss: 0.5803 - acc: 0.7500 - val_loss: 0.5543 - val_acc: 0.8205
# — val_f1: 0.800000 — val_precision: 0.800000 — val_recall 0.800000
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.79      0.79        19
#            1       0.80      0.80      0.80        20
#
#     accuracy                           0.79        39
#    macro avg       0.79      0.79      0.79        39
# weighted avg       0.79      0.79      0.79        39
#
#
# Epoch 5/6
# 116/116 [==============================] - 0s 4ms/step - loss: 0.4967 - acc: 0.8017 - val_loss: 0.5557 - val_acc: 0.7436
# — val_f1: 0.250000 — val_precision: 0.750000 — val_recall 0.150000
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.51      0.95      0.67        19
#            1       0.75      0.15      0.25        20
#
#     accuracy                           0.54        39
#    macro avg       0.63      0.55      0.46        39
# weighted avg       0.64      0.54      0.45        39
#
#
# Epoch 6/6
# 116/116 [==============================] - 0s 4ms/step - loss: 0.4465 - acc: 0.8103 - val_loss: 0.5681 - val_acc: 0.7179
# — val_f1: 0.181818 — val_precision: 1.000000 — val_recall 0.100000
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.51      1.00      0.68        19
#            1       1.00      0.10      0.18        20
#
#     accuracy                           0.54        39
#    macro avg       0.76      0.55      0.43        39
# weighted avg       0.76      0.54      0.42        39
# generating classfication report
# Accuracy: 58.974359
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.58      0.75      0.65        20
#            1       0.62      0.42      0.50        19
#
#     accuracy                           0.59        39
#    macro avg       0.60      0.59      0.58        39
# weighted avg       0.60      0.59      0.58        39
#
#
# job finished
# ********************
# year 2016
# length of users 2642
# length of the data 9456
# users 2642
# cleanining the data
# HBox(children=(IntProgress(value=0, max=9456), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=9456), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=9456), HTML(value='')))
# max_length 17
# total users before 2642
# length of positive samples before 313
# length of positive samples after 313
# total users after 626
# before data 9456
# users before 2642
# after data 2878
# after users 626
# preparing the tokenizer
# vocalb 4669
# creating glove embeddign matrix
# encoding the data
# X (626, 17)
# y (626,)
# train-test split
# X-train (375, 17)
# X-test (126, 17)
# creating lstm model
# creating model
# compiling the model
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         (None, 17)                0
# _________________________________________________________________
# embedding_6 (Embedding)      (None, 17, 100)           466900
# _________________________________________________________________
# bidirectional_6 (Bidirection (None, 17, 200)           160800
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 3400)              0
# _________________________________________________________________
# dense_11 (Dense)             (None, 100)               340100
# _________________________________________________________________
# dense_12 (Dense)             (None, 2)                 202
# =================================================================
# Total params: 968,002
# Trainable params: 968,002
# Non-trainable params: 0
# _________________________________________________________________
# training the model with balance dataset
# Train on 375 samples, validate on 125 samples
# Epoch 1/6
# 375/375 [==============================] - 6s 17ms/step - loss: 0.6773 - acc: 0.6187 - val_loss: 0.7031 - val_acc: 0.5920
# — val_f1: 0.532110 — val_precision: 0.617021 — val_recall 0.467742
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.58      0.71      0.64        63
#            1       0.62      0.47      0.53        62
#
#     accuracy                           0.59       125
#    macro avg       0.60      0.59      0.59       125
# weighted avg       0.60      0.59      0.59       125
#
#
# Epoch 2/6
# 375/375 [==============================] - 1s 4ms/step - loss: 0.6270 - acc: 0.6667 - val_loss: 0.6988 - val_acc: 0.5760
# — val_f1: 0.318182 — val_precision: 0.538462 — val_recall 0.225806
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.52      0.81      0.63        63
#            1       0.54      0.23      0.32        62
#
#     accuracy                           0.52       125
#    macro avg       0.53      0.52      0.47       125
# weighted avg       0.53      0.52      0.48       125
#
#
# Epoch 3/6
# 375/375 [==============================] - 1s 4ms/step - loss: 0.5729 - acc: 0.7120 - val_loss: 0.7537 - val_acc: 0.5840
# — val_f1: 0.550459 — val_precision: 0.638298 — val_recall 0.483871
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.59      0.73      0.65        63
#            1       0.64      0.48      0.55        62
#
#     accuracy                           0.61       125
#    macro avg       0.61      0.61      0.60       125
# weighted avg       0.61      0.61      0.60       125
#
#
# Epoch 4/6
# 375/375 [==============================] - 1s 4ms/step - loss: 0.5239 - acc: 0.7280 - val_loss: 0.8440 - val_acc: 0.6000
# — val_f1: 0.558559 — val_precision: 0.632653 — val_recall 0.500000
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.59      0.71      0.65        63
#            1       0.63      0.50      0.56        62
#
#     accuracy                           0.61       125
#    macro avg       0.61      0.61      0.60       125
# weighted avg       0.61      0.61      0.60       125
#
#
# Epoch 5/6
# 375/375 [==============================] - 1s 4ms/step - loss: 0.4806 - acc: 0.7627 - val_loss: 0.8585 - val_acc: 0.5520
# — val_f1: 0.337079 — val_precision: 0.555556 — val_recall 0.241935
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.52      0.81      0.63        63
#            1       0.56      0.24      0.34        62
#
#     accuracy                           0.53       125
#    macro avg       0.54      0.53      0.49       125
# weighted avg       0.54      0.53      0.49       125
#
#
# Epoch 6/6
# 375/375 [==============================] - 1s 4ms/step - loss: 0.4224 - acc: 0.8000 - val_loss: 0.9481 - val_acc: 0.5680
# — val_f1: 0.435644 — val_precision: 0.564103 — val_recall 0.354839
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.53      0.73      0.62        63
#            1       0.56      0.35      0.44        62
#
#     accuracy                           0.54       125
#    macro avg       0.55      0.54      0.53       125
# weighted avg       0.55      0.54      0.53       125
# generating classfication report
# Accuracy: 65.873016
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.64      0.73      0.68        63
#            1       0.69      0.59      0.63        63
#
#     accuracy                           0.66       126
#    macro avg       0.66      0.66      0.66       126
# weighted avg       0.66      0.66      0.66       126
#
#
# job finished
# ********************
# year 2017
# length of users 42784
# length of the data 120873
# users 42784
# cleanining the data
# HBox(children=(IntProgress(value=0, max=120873), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=120873), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=120873), HTML(value='')))
# max_length 26
# total users before 42784
# length of positive samples before 9525
# length of positive samples after 9525
# total users after 19050
# before data 120873
# users before 42784
# after data 63890
# after users 19050
# preparing the tokenizer
# vocalb 16490
# creating glove embeddign matrix
# encoding the data
# X (19050, 26)
# y (19050,)
# train-test split
# X-train (11430, 26)
# X-test (3810, 26)
# creating lstm model
# creating model
# compiling the model
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         (None, 26)                0
# _________________________________________________________________
# embedding_7 (Embedding)      (None, 26, 100)           1649000
# _________________________________________________________________
# bidirectional_7 (Bidirection (None, 26, 200)           160800
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 5200)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 100)               520100
# _________________________________________________________________
# dense_14 (Dense)             (None, 2)                 202
# =================================================================
# Total params: 2,330,102
# Trainable params: 2,330,102
# Non-trainable params: 0
# _________________________________________________________________
# training the model with balance dataset
# Train on 11430 samples, validate on 3810 samples
# Epoch 1/6
# 11430/11430 [==============================] - 72s 6ms/step - loss: 0.6430 - acc: 0.6557 - val_loss: 0.6199 - val_acc: 0.6769
# — val_f1: 0.681279 — val_precision: 0.669539 — val_recall 0.693438
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.68      0.66      0.67      1905
#            1       0.67      0.69      0.68      1905
#
#     accuracy                           0.68      3810
#    macro avg       0.68      0.68      0.68      3810
# weighted avg       0.68      0.68      0.68      3810
#
#
# Epoch 2/6
# 11430/11430 [==============================] - 68s 6ms/step - loss: 0.6162 - acc: 0.6746 - val_loss: 0.6070 - val_acc: 0.6848
# — val_f1: 0.632266 — val_precision: 0.726653 — val_recall 0.559580
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.64      0.79      0.71      1905
#            1       0.73      0.56      0.63      1905
#
#     accuracy                           0.67      3810
#    macro avg       0.68      0.67      0.67      3810
# weighted avg       0.68      0.67      0.67      3810
#
#
# Epoch 3/6
# 11430/11430 [==============================] - 68s 6ms/step - loss: 0.5948 - acc: 0.6882 - val_loss: 0.6153 - val_acc: 0.6885
# — val_f1: 0.632489 — val_precision: 0.731724 — val_recall 0.556955
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.64      0.80      0.71      1905
#            1       0.73      0.56      0.63      1905
#
#     accuracy                           0.68      3810
#    macro avg       0.69      0.68      0.67      3810
# weighted avg       0.69      0.68      0.67      3810
#
#
# Epoch 4/6
# 11430/11430 [==============================] - 68s 6ms/step - loss: 0.5680 - acc: 0.7063 - val_loss: 0.6174 - val_acc: 0.6911
# — val_f1: 0.599751 — val_precision: 0.738296 — val_recall 0.504987
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.62      0.82      0.71      1905
#            1       0.74      0.50      0.60      1905
#
#     accuracy                           0.66      3810
#    macro avg       0.68      0.66      0.65      3810
# weighted avg       0.68      0.66      0.65      3810
#
#
# Epoch 5/6
# 11430/11430 [==============================] - 69s 6ms/step - loss: 0.5335 - acc: 0.7286 - val_loss: 0.6555 - val_acc: 0.6808
# — val_f1: 0.573713 — val_precision: 0.734043 — val_recall 0.470866
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.61      0.83      0.70      1905
#            1       0.73      0.47      0.57      1905
#
#     accuracy                           0.65      3810
#    macro avg       0.67      0.65      0.64      3810
# weighted avg       0.67      0.65      0.64      3810
#
#
# Epoch 6/6
# 11430/11430 [==============================] - 68s 6ms/step - loss: 0.5000 - acc: 0.7486 - val_loss: 0.7147 - val_acc: 0.6795
# — val_f1: 0.548638 — val_precision: 0.717557 — val_recall 0.444094
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.60      0.83      0.69      1905
#            1       0.72      0.44      0.55      1905
#
#     accuracy                           0.63      3810
#    macro avg       0.66      0.63      0.62      3810
# weighted avg       0.66      0.63      0.62      3810
# generating classfication report
# Accuracy: 66.902887
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.66      0.71      0.68      1905
#            1       0.68      0.63      0.66      1905
#
#     accuracy                           0.67      3810
#    macro avg       0.67      0.67      0.67      3810
# weighted avg       0.67      0.67      0.67      3810
#
#
# job finished

# %% [markdown]
# #### basline models

# %%
svm_scores = []
svm_models= []
rf_models= []
rf_scores = []
maj_scores = []
tfidf_list = []
xgb_scores = []
xgb_models = []
for year,data,users_lbl in bucket_list:
    print("********************")
    print("year",year)
    print("length of users",len(users_lbl))
    final = run_baslines(data,users_lbl,)
    svm_model,svm_score = final["svm"]
    rf_model, rf_score = final["rf"]
    xgb_model,xgb_score = final["xg_boost"]
    tf_idf = final["tf-idf"]
    maj_score = final["maj"]
    tfidf_list.append(tf_idf)
    svm_scores.append(svm_score)
    svm_models.append(svm_model)
    rf_scores.append(rf_score)
    rf_models.append(rf_model)
    xgb_scores.append(xgb_score)
    xgb_models.append(xgb_model)
    maj_scores.append(maj_score)
# Out:
# ********************
# year 2015
# length of users 1049
# HBox(children=(IntProgress(value=0, max=2944), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=2944), HTML(value='')))
# preparing the tokenizer
# downsampling
# downsampled data length (194, 5572)
# train-test split
# training the models
# svm
# [LibLinear]rf
# xgBoost
# predicting scores
# svm
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.65      0.65      0.65        20
#            1       0.63      0.63      0.63        19
#
#     accuracy                           0.64        39
#    macro avg       0.64      0.64      0.64        39
# weighted avg       0.64      0.64      0.64        39
#
#
# random_forest
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.50      0.50      0.50        20
#            1       0.47      0.47      0.47        19
#
#     accuracy                           0.49        39
#    macro avg       0.49      0.49      0.49        39
# weighted avg       0.49      0.49      0.49        39
#
#
# xgboost
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.40      0.40      0.40        20
#            1       0.37      0.37      0.37        19
#
#     accuracy                           0.38        39
#    macro avg       0.38      0.38      0.38        39
# weighted avg       0.38      0.38      0.38        39
#
#
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        20
#            1       0.49      1.00      0.66        19
#
#     accuracy                           0.49        39
#    macro avg       0.24      0.50      0.33        39
# weighted avg       0.24      0.49      0.32        39
#
#
# job finished
# ********************
# year 2016
# length of users 2642
# HBox(children=(IntProgress(value=0, max=9456), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=9456), HTML(value='')))
# preparing the tokenizer
# downsampling
# downsampled data length (626, 9745)
# train-test split
# training the models
# svm
# [LibLinear]rf
# xgBoost
# predicting scores
# svm
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.56      0.59      0.57        63
#            1       0.57      0.54      0.55        63
#
#     accuracy                           0.56       126
#    macro avg       0.56      0.56      0.56       126
# weighted avg       0.56      0.56      0.56       126
#
#
# random_forest
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.56      0.86      0.68        63
#            1       0.70      0.33      0.45        63
#
#     accuracy                           0.60       126
#    macro avg       0.63      0.60      0.57       126
# weighted avg       0.63      0.60      0.57       126
#
#
# xgboost
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.54      0.73      0.62        63
#            1       0.59      0.38      0.46        63
#
#     accuracy                           0.56       126
#    macro avg       0.56      0.56      0.54       126
# weighted avg       0.56      0.56      0.54       126
#
#
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        63
#            1       0.50      1.00      0.67        63
#
#     accuracy                           0.50       126
#    macro avg       0.25      0.50      0.33       126
# weighted avg       0.25      0.50      0.33       126
#
#
# job finished
# ********************
# year 2017
# length of users 42784
# HBox(children=(IntProgress(value=0, max=120873), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=120873), HTML(value='')))
# preparing the tokenizer
# downsampling
# downsampled data length (19050, 23748)
# train-test split
# training the models
# svm
# [LibLinear]rf
# xgBoost
# predicting scores
# svm
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.62      0.71      0.66      1905
#            1       0.66      0.57      0.61      1905
#
#     accuracy                           0.64      3810
#    macro avg       0.64      0.64      0.64      3810
# weighted avg       0.64      0.64      0.64      3810
#
#
# random_forest
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.60      0.77      0.68      1905
#            1       0.68      0.50      0.57      1905
#
#     accuracy                           0.63      3810
#    macro avg       0.64      0.63      0.63      3810
# weighted avg       0.64      0.63      0.63      3810
#
#
# xgboost
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.65      0.74      0.69      1905
#            1       0.70      0.60      0.65      1905
#
#     accuracy                           0.67      3810
#    macro avg       0.67      0.67      0.67      3810
# weighted avg       0.67      0.67      0.67      3810
#
#
#   Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      1905
#            1       0.50      1.00      0.67      1905
#
#     accuracy                           0.50      3810
#    macro avg       0.25      0.50      0.33      3810
# weighted avg       0.25      0.50      0.33      3810
#
#
# job finished

# %%
### plot with cumulative data
plt.figure(figsize=(15,7))
spans = ["2014-15","2014-16","2014-17"]
plt.plot(spans,lstm_scores,label="lstm")
plt.plot(spans,(3*[maj_score]),label="majority classifier")
plt.plot(spans,svm_scores,label="svm")
plt.plot(spans,rf_scores,label="rf")
plt.plot(spans,xgb_scores,label="xg_boost")
plt.title("looking at performcnce of classfiers on different range year (downsampled) data cumulative")
plt.ylabel("weighted F1 score")
plt.legend()
plt.show()

# %%
## most descriptive words by year
for svm,tf_idf,year in zip(svm_models,tfidf_list,spans):
    print(year)
    plot_coeff(20,svm,tf_idf.get_feature_names())

# %%
## without downsampling of data
fig, ax = plt.subplots(figsize = (10,6))
x_label = ["2015","205-16","2015-17"]
ax.plot(x_label,lstm_scores,label="lstm")
ax.plot(x_label,svm_scores,label="svm")
ax.plot(x_label,rf_scores,label="rf")
ax.plot(x_label,majority,label="majority classifier")
plt.title("Change of accuarcy of classifier to recongnize mono- > poly on different range of data",fontsize=14)
plt.xlabel("date range",fontsize=12)
plt.ylabel("f1 score of the classifier",fontsize=12)
plt.legend()
plt.show()
