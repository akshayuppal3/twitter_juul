# %%
#mongo DB connection

# %%
import pymongo
from pymongo import MongoClient
import networkx as nx
import pprint

# %%
client = MongoClient("localhost:27017")
print(client.twitter.juul)
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'twitter'), 'juul')

# %%
pipeline = [
    {
        '$match' : {'parentID': "None"}
    }
]
pprint.pprint(list(client.twitter.juul.aggregate(pipeline)))
# Out:
# [{'': 0,
#   '_id': ObjectId('5b933368f2d4a84c8d2afab8'),
#   'favourites_count': 510,
#   'friendList': '[154311445, 808721923433709568, 482133423, '
#                 '837114934735458304, 151936506]',
#   'friendsCount': 1269,
#   'imageurl': 'http://pbs.twimg.com/profile_images/1031674711581720576/FegcdZKK_normal.jpg',
#   'parentID': 'None',
#   'tweetId': 1038205565313286144,
#   'userCreatedAt': '2010-07-27 21:01:54',
#   'userDescription': 'Prevent. Educate. Celebrate. Saving lives, one tweet at '
#                      'a time.',
#   'userFollowersCount': 608,
#   'userID': 171647353,
#   'userName': 'NCPC'},
#  {'': 6,
#   '_id': ObjectId('5b933368f2d4a84c8d2afabe'),
#   'favourites_count': 5620,
#   'friendList': '[1001874108244774917, 43812483, 22666390, 46917651, '
#                 '2343994460]',
#   'friendsCount': 482,
#   'imageurl': 'http://pbs.twimg.com/profile_images/851106867338256385/h2Y7TlIr_normal.jpg',
#   'parentID': 'None',
# ...
