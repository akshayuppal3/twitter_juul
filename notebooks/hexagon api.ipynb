# %%
import requests
import urllib.request
import json
import pandas as pd

# %%
url = "https://api.crimsonhexagon.com/api/authenticate"
def getAuthToken():
    querystring = {
      "username":"auppal8@uic.edu",
      "noExpiration":"true",
      "password":"Xperia123"
    }
    response = requests.request("GET",headers={},url=url, params=querystring)
    if (response.status_code == 200):
        result = response.json()
        authToken = result['auth']
        authToken = "&auth=" +authToken
        return (authToken)

# %%
base = 'https://api.crimsonhexagon.com/api/monitor'
def make_endpoint(endpoint):
    return '{}/{}?'.format(base, endpoint)

# %%
session = requests.Session()
from_ = '2017-07-01'
to_ = '2018-09-25'
monitorID = "11553243040" #The ID for your monitor

# %%
##calling the api -- not working
endpoint = make_endpoint('posts')
print(endpoint)
payload = {
            'auth': getAuthToken(),
            'id': monitorID,
            'start': from_,
            'end': to_,
            'extendLimit': 'true',
            'fullContents': 'true'
        }
r = session.get(endpoint,params = payload)
print(r)
# Out:
# https://api.crimsonhexagon.com/api/monitor/posts?
# Connected
# <Response [403]>

# %%
def getAuth():
    username = "auppal8@uic.edu"
    password = "Xperia123"
    authToken = "&auth?"+"username="+username+"&password="+password
#     print(authToken)
    return authToken

# %%
def getURL(): #provides URL for Crimson API
    urlStart = "https://api.crimsonhexagon.com/api"
    return urlStart

# %%
urlStart = "https://api.crimsonhexagon.com/api"
startDate = '2017-07-01'
endDate = '2018-09-25'
dates = "&start="+startDate+"&end="+endDate #Combines start and end date into format needed for API call

# %%
monitorID = "11553243040" # "juulMonitor" #The ID for your monitor
dates = "&start="+startDate+"&end="+endDate #Combines start and end date into format needed for API call
urlStart = getURL() #Gets URL
authToken = getAuthToken() #Gets auth token
endpoint = "/monitor/posts?id="; #endpoint needed for this query
extendLimit = "&extendLimit=true" #extends call number from 500 to 10,000
fullContents = "&fullContents=true" #Brings back full contents for Blog and Tumblr posts which are usually truncated around search keywords. This can occasionally disrupt CSV formatting.
# Out:
# Connected

# %%
#original
urlData = urlStart+endpoint+monitorID+authToken+dates+extendLimit+fullContents 
print(urlData)
# Out:
# https://api.crimsonhexagon.com/api/monitor/posts?id=11553243040&auth=5gAPwiI9pqUcPBWHZ1W1ElnCydv96-om2BfiZXdbS04&start=2017-07-01&end=2018-09-25&extendLimit=true&fullContents=true

# %%
webURL = urllib.request.urlopen(urlData)
data = webURL.read().decode('utf8')
theJSON = json.loads(data)
print(theJSON)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
print(theJSON['posts'][55])
# Out:
# {'url': 'http://twitter.com/TheRealWapshott/status/965705558643920896', 'title': '', 'type': 'Twitter', 'location': 'GBR', 'geolocation': {'id': 'GBR', 'name': 'United Kingdom', 'country': 'GBR'}, 'language': 'en', 'authorKlout': 0, 'assignedCategoryId': 9926161247, 'assignedEmotionId': 9926161242, 'categoryScores': [{'categoryId': 9926161248, 'categoryName': 'Basic Neutral', 'score': 0.0}, {'categoryId': 9926161247, 'categoryName': 'Basic Positive', 'score': 1.0}, {'categoryId': 9926161241, 'categoryName': 'Basic Negative', 'score': 0.0}], 'emotionScores': [{'emotionId': 9926161239, 'emotionName': 'Sadness', 'score': 0.02}, {'emotionId': 9926161249, 'emotionName': 'Anger', 'score': 0.0}, {'emotionId': 9926161246, 'emotionName': 'Disgust', 'score': 0.01}, {'emotionId': 9926161245, 'emotionName': 'Fear', 'score': 0.01}, {'emotionId': 9926161244, 'emotionName': 'Neutral', 'score': 0.36}, {'emotionId': 9926161243, 'emotionName': 'Surprise', 'score': 0.03}, {'emotionId': 9926161242, 'emotionName': 'Joy', 'score': 0.57}]}

# %%
for i in theJSON['posts']:
    if ('date' in i): #identifies date posted
        tempDate = str(i["date"])
        dateTime = tempDate.split("T")
        postDates[c] = dateTime[0]
        postTimes[c] = dateTime[1]
    print(i["url"])
    print(i["language"])
    print(i["type"])

# %%
#     print(i["contents"])
#     print(i["authors"])
#     print(i["author"])
#     print(i["locations"])
#     if ('categoryScores' in i): #finds sentiment value and matching attribute
#         for l in i["categoryScores"]:
#             catName = l["categoryName"]
#             if catName == "Basic Neutral":
#                 neutralScore[c] = l["score"]
#             elif catName =="Basic Positive":
#                 positiveScore[c] = l["score"]
#             elif catName == "Basic Negative":
#                 negativeScore[c] = l["score"]

# %%
import hexogon

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ob = hexogon.Hexagon()
df = ob.hexagonData
df2 = ob.getTwitterData(df)
# Out:
# batchSize =  3

# %%
df.keys()
# Out:
# Index(['tweetID', 'url', 'type', 'title', 'location', 'language'], dtype='object')

# %%
df2
# Out:
#                  tweetId               userID  \
# 0    1045248451305398272             55814586
# 1    1045734900756860928           2918018660
# 2    1044640869163421696             15480029
# 3    1044862909405417472             61864801
# 4    1046577170561282049  1008505152654004224
# 5    1044942540812800001  1009445927491395585
# 6    1044642857192214528             14335586
# 7    1044709737034584064            379316516
# 8    1045377531250180099            358142191
# 9    1044682073439711232   984146978757103619
# 10   1045825706545074176  1029437205440339968
# 11   1045323234487545857   789968856450301952
# 12   1044712035886362626           1418655649
# 13   1044639444257701889            831302293
# 14   1045735030230790144   830846409150705664
# 15   1044841557009059841            724738674
# 16   1044968374298705922              9804562
# 17   1044638554356436993   865698981602623489
# 18   1044720223914463232            527486643
# 19   1044655345883336705             30001583
# 20   1046406384219238400             28912613
# 21   1044639431108513794           2789908445
# 22   1044710651870896128             32293779
# 23   1044815099091922944           2335665432
# 24   1044638967809921024              8002182
# 25   1044774755147014144             37459590
# 26   1045062979396362241            629084145
# 27   1045749100874883072   916808036542324736
# 28   1044812174777102342           3997870336
# 29   1045473187759251456   809229705073147904
# ..                   ...                  ...
# 269  1045938305567793152  1022134613639147520
# 270  1045100643290107904           3119313208
# 271  1045900620765499393  1036313946645561345
# 272  1045397335260516352             23484353
# 273  1045820456299749376            535965453
# 274  1045012974371524608            574595653
# 275  1045309684457107458            486843768
# 276  1044615029566377984           2217673863
# 275  JUUL PODS THURSDAY 🎉🎉🎉\n5% OFF 🎉🎉🎉\n#juul #juu...     None
# 276  who has a #juul #pod i can have for free on th...     None
# 277  How long can you go without JUULing #juul #juu...     None
# 278  RT @CStoreNews_: These are the fastest-growing...     None
# 279  RT @shefield24: #Juul  just landed and the pod...     None
# 280  For the month of October  25% to 50% off E Liq...     None
# 281  RT @TLGcanadaCorp: New JC-01 salt nic kits hav...     None
# 282  *Throws up from either #juul or a fever\nMe: (...     None
# 283  @JUULvapor good work, never thought the vape g...     None
# 284  Someone left their #juul in my vehicle #uber #...     None
# 285  @tylerpetty43 @SwaggerSouls I gotchu homie.. N...     None
# 286  Juul isn't only culprit in teen e-cigarette sm...     None
# 287  My Quit Smoking Story! https://t.co/CGTVGCu9pR...     None
# 288  Proprietary chargers are the worst @zOMbEEmODe...     None
# 289  Do you have ever seen transformable pod? Here ...     None
# 290  Excited to share the latest addition to my #et...     None
# 291  All New Styles available now! $12.99 for a 3 p...     None
# 292  I wish it mad the sound when he breaks it but ...     None
# 293  RT ejuicesteals: 20% Off Juul Pods Only $12.79...     None
# 294  You would think a gutter wouldn't be a good se...     None
# 295  Close call. Thanks #Juul # https://t.co/RbkMRr...     None
# 296  RT @commanda_z: Things I’ve done at work today...     None
# 297  #juul you save me from going insane in the bra...     None
# 298  The latest Medicina 2.0! https://t.co/OTU08fm2...     None
#
#      favourites_count               userLocation               userName  \
# 0                1221                         RO           Eugen Platon
# 1                 663              San Francisco                   JUUL
# 2                1667                Augusta, GA     Ayman Hossam Fadel
# 3                1838                   On Earth         Lucky Or. Good
# 4                   5               Kingston, NY             The Yetaay
# 5                   0                                     alicryptolife
# 6                5382             Washington, DC         Public Citizen
# 7                6842         Seferihisar, İzmir           Pabloescobar
# 8                 292                 Boston, MA      Thornton Law Firm
# 9                  13                                      Kevin Ichaso
# 10                479                                       VapeForLife
# 11               5493              United States                   Mstr
# 12                205                   Reno, NV   David Michael Slater
# 13               6281                                          RonInCMH
# 14                  0                                  Your Insta Babes
# 15                202                                      Triston Reid
# 16              11704              Frederick, MD      andrew wright 🐿 🔥
# 17              45634           NE Oklahoma, USA               DeeDubya
# 18               2089            New Jersey, USA              Jim Lucas
# 19               1240                 Boston, MA                   CCFC
# 20               2548                                      Kyle Valanne
# 21               5108                                   Taylor Billings
# 22               2140  where you'd least suspect                    avc
# 23               2990         Seattle Washington       From Where I Sit
# 24               9511                Detroit, MI          Walid Damouny
# 25                 40                ᴍᴀʟᴀʏꜱɪᴀ 🇲🇾                ᴊᴏᴇ ʟᴇᴇ
# 26                 42                                       GeekinfoNow
# 27                327            Los Angeles, CA          twatter mouth
# 28              10924                                    Bibi Spielberg
# 29               3403                                   eStream Studios
# ..                ...                        ...                    ...
# 269                 8                                        Goat Memes
# 270                 4                         UK        @CloudChasingUK
# 271              2073             Canada and USA                   acap
# 272               227                                          PondScum
# 284  http://pbs.twimg.com/profile_images/9911395616...                 743
# 285  http://pbs.twimg.com/profile_images/1038479591...                   4
# 286  http://pbs.twimg.com/profile_images/7253173944...                 439
# 287  http://pbs.twimg.com/profile_images/7389707185...                  35
# 288  http://pbs.twimg.com/profile_images/1675552160...                  97
# 289  http://pbs.twimg.com/profile_images/8425503070...                 417
# 290  http://pbs.twimg.com/profile_images/1038479591...                   4
# 291  http://pbs.twimg.com/profile_images/1038479591...                   4
# 292  http://pbs.twimg.com/profile_images/1046573457...                  89
# 293  http://pbs.twimg.com/profile_images/8620818696...                1625
# 294  http://pbs.twimg.com/profile_images/1043246995...                  82
# 295  http://pbs.twimg.com/profile_images/1039621625...                  80
# 296  http://pbs.twimg.com/profile_images/1045140529...                 978
# 297  http://pbs.twimg.com/profile_images/1044881196...                  16
# 298  http://pbs.twimg.com/profile_images/1002220427...                1211
#
#      friendsCount friendList  retweetCount  retweeted lang
# 0            3736       None             0      False   en
# 1             371       None             5      False   en
# 2            2119       None            25      False   en
# 3             694       None            25      False   en
# 4               8       None             0      False   en
# 5            2707       None             1      False   en
# 6            5415       None            25      False   en
# 7            1228       None             3      False   en
# 8            2612       None             0      False   en
# 9              11       None             0      False   en
# 10             32       None             1      False   en
# 11            791       None             0      False   en
# 12           1953       None            25      False   en
# 13           1292       None            25      False   en
# 14              2       None             0      False   en
# 15           1272       None             0      False   en
# 16           2646       None             0      False   en
# 17            250       None            25      False   en
# 18            230       None            25      False   en
# 19           2227       None            25      False   en
# 20            158       None             1      False   en
# 21           1291       None            25      False   en
# 22           4876       None             3      False   en
# 23            758       None            25      False   en
# 24           2906       None            25      False   en
# 25            274       None             3      False   en
# 26             81       None             0      False   en
# 27            229       None             0      False   en
# 28          12841       None             3      False   en
# 29          12093       None             0      False   en
# ..            ...        ...           ...        ...  ...
# 269             8       None             0      False   en
# 270           916       None             1      False   en
# 271           235       None             0      False   en
# 272           364       None             1      False   en
# 273           227       None             4      False   en
# 274           325       None             2      False   en
# 275            30       None             0      False   en
# 276           590       None             0      False   en
# 277          4971       None             0      False   en
# 278         55181       None             6      False   en
# 279           957       None             4      False   en
# 280            43       None             1      False   en
# 281           957       None             2      False   en
# 282          1114       None             0      False   en
# 283            93       None             0      False   en
# 284          1027       None             0      False   en
# 285            17       None             0      False   en
# 286           966       None             0      False   en
# 287            86       None             0      False   en
# 288           280       None             0      False   en
# 289           497       None             0      False   en
# 290            17       None             0      False   en
# 291            17       None             0      False   en
# 292           199       None             0      False   en
# 293          1228       None             0      False   en
# 294            55       None             2      False   en
# 295           117       None             1      False   en
# 296           550       None             1      False   en
# 297            61       None             0      False   en
# 298          1151       None             0      False   en
#
# [299 rows x 16 columns]

# %%
ob.id
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-85-e4612f44e23f> in <module>()
# ----> 1 ob.id
#
# AttributeError: 'dict' object has no attribute 'id'
